# %% [markdown]
# # Azure Computer Vision 4 (Florence)
#
# ## Image Analysis with Azure Computer Vision 4
#
# ![Image](florence.jpg)
#
# The **Computer Vision Image Analysis** service can extract a wide variety of visual features from your images. For example, it can determine whether an image contains adult content, find specific brands or objects, or find human faces.
#
# The latest version of Image Analysis, 4.0, which is now in public preview, has new features like synchronous OCR and people detection. We recommend you use this version going forward.
#
# You can use Image Analysis through a client library SDK or by calling the REST API directly. Follow the quickstart to get started.
#
# https://learn.microsoft.com/en-us/azure/cognitive-services/computer-vision/overview-image-analysis?tabs=4-0
#
# Azure Computer Vision updates:
# https://learn.microsoft.com/en-us/azure/cognitive-services/computer-vision/whats-new#march-2023
# <br><br>
# > Serge Retkowsky | Microsoft | https://github.com/retkowsky | 3rd of May, 2023

# %%
import os
import requests
import sys

from dotenv import load_dotenv
from PIL import Image
from pprintjson import pprintjson

# %%
sys.version
# Out:
# '3.11.1 (main, Mar 24 2023, 00:55:06) [GCC 11.3.0]'

# %% [markdown]
# ## Azure Computer Vision 4

# %%
load_dotenv("azure.env")

key = os.getenv("azure_cv_key")
endpoint = os.getenv("azure_cv_endpoint")

# %%
options = "&features=tags,objects,caption,read,smartCrops,denseCaptions,people"
model = "?api-version=2023-02-01-preview&modelVersion=latest"

url = endpoint + "/computervision/imageanalysis:analyze" + model + options

headers = {"Content-type": "application/octet-stream", "Ocp-Apim-Subscription-Key": key}

# %% [markdown]
# ## Images

# %%
IMAGES_DIR = "images"

image_extensions = (".jpg", ".jpeg", ".png", ".gif")
image_files = [f for f in os.listdir(IMAGES_DIR) if f.endswith(image_extensions)]
image_files
# Out:
# ['arc_triomphe.jpg',
#  'businesscard.jpg',
#  'car.jpg',
#  'car.png',
#  'car2.jpg',
#  'cars.jpg',
#  'cat.jpg',
#  'drinks.jpg',
#  'fashionprocess.png',
#  'fruits.jpg',
#  'image1.jpg',
#  'office.jpg',
#  'postalcard.jpg',
#  'presentation.png',
#  'sand.jpg',
#  'street.jpg',
#  'tomato.jpg',
#  'whitecar.jpg']

# %% [markdown]
# ## Test 1

# %%
image_file = os.path.join(IMAGES_DIR, "presentation.png")

img = Image.open(image_file)
img.thumbnail((640, 640), Image.LANCZOS)
img.convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
with open(image_file, "rb") as f:
    data = f.read()

r = requests.post(url, data=data, headers=headers)

results = r.json()
pprintjson(results)
# Out:
# {
#     "captionResult": {
#         "text": "a man pointing at a screen",
#         "confidence": 1.0
#     },
#     "objectsResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 655,
#                     "y": 83,
#                     "w": 263,
#                     "h": 605
#                 },
#                 "tags": [
#                     {
#                         "name": "person",
#                         "confidence": 0.905
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 75,
#                     "y": 76,
#                     "w": 678,
#                     "h": 414
#                 },
#                 "tags": [
#                     {
#                         "name": "television",
#                         "confidence": 0.808
#                     }
#                 ]
#             }
#         ]
#     },
#     "readResult": {
#         "stringIndexType": "TextElements",
#         "content": "9:35 AM\nE Conference room 154584354\n#: 555-173-4547\nTown Hall\n9:00 AM - 10:00 AM\nAaron Buaion\nDaily SCRUM\n10:00 AM 11:00 AM\nChurlette de Crum\nQuarterly NI Hands\n11.00 AM-12:00 PM\nBebek Shaman\nWeekly stand up\n12:00 PM-1:00 PM\nDelle Marckre\nProduct review",
#         "pages": [
#             {
#                 "height": 692.0,
#                 "width": 1038.0,
#                 "angle": 0.3048,
#                 "pageNumber": 1,
#                 "words": [
#                     {
#                         "content": "9:35",
#                         "boundingBox": [
#                             131.0,
#                             130.0,
#                             171.0,
#                             130.0,
#                             171.0,
#                             149.0,
#                             130.0,
#                             149.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 0,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             179.0,
#                             130.0,
#                             204.0,
#                             130.0,
#                             203.0,
#                             149.0,
#                             178.0,
#                             149.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 5,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "E",
#                         "boundingBox": [
#                             131.0,
#                             154.0,
#                             135.0,
#                             154.0,
#                             135.0,
#                             161.0,
#                             131.0,
#                             161.0
#                         ],
#                         "confidence": 0.104,
#                         "span": {
#                             "offset": 8,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "Conference",
#                         "boundingBox": [
#                             142.0,
#                             154.0,
#                             174.0,
#                             154.0,
#                             173.0,
#                             161.0,
#                             141.0,
#                             161.0
#                         ],
#                         "confidence": 0.902,
#                         "span": {
#                             "offset": 10,
#                             "length": 10
#                         }
#                     },
#                     {
#                         "content": "room",
#                         "boundingBox": [
#                             175.0,
#                             154.0,
#                             189.0,
#                             155.0,
#                             188.0,
#                             161.0,
#                             175.0,
#                             161.0
#                         ],
#                         "confidence": 0.796,
#                         "span": {
#                             "offset": 21,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "154584354",
#                         "boundingBox": [
#                             192.0,
#                             155.0,
#                             224.0,
#                             154.0,
#                             223.0,
#                             162.0,
#                             191.0,
#                             161.0
#                         ],
#                         "confidence": 0.864,
#                         "span": {
#                             "offset": 26,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "#:",
#                         "boundingBox": [
#                             131.0,
#                             163.0,
#                             139.0,
#                             164.0,
#                             139.0,
#                             171.0,
#                             131.0,
#                             171.0
#                         ],
#                         "confidence": 0.036,
#                         "span": {
#                             "offset": 36,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "555-173-4547",
#                         "boundingBox": [
#                             142.0,
#                             164.0,
#                             182.0,
#                             165.0,
#                             181.0,
#                             171.0,
#                             142.0,
#                             171.0
#                         ],
#                         "confidence": 0.597,
#                         "span": {
#                             "offset": 39,
#                             "length": 12
#                         }
#                     },
#                     {
#                         "content": "Town",
#                         "boundingBox": [
#                             547.0,
#                             181.0,
#                             568.0,
#                             181.0,
#                             568.0,
#                             190.0,
#                             546.0,
#                             191.0
#                         ],
#                         "confidence": 0.981,
#                         "span": {
#                             "offset": 52,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Hall",
#                         "boundingBox": [
#                             570.0,
#                             181.0,
#                             590.0,
#                             181.0,
#                             590.0,
#                             191.0,
#                             570.0,
#                             190.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 57,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "9:00",
#                         "boundingBox": [
#                             546.0,
#                             192.0,
#                             555.0,
#                             192.0,
#                             555.0,
#                             200.0,
#                             546.0,
#                             200.0
#                         ],
#                         "confidence": 0.09,
#                         "span": {
#                             "offset": 62,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             557.0,
#                             192.0,
#                             565.0,
#                             192.0,
#                             565.0,
#                             200.0,
#                             557.0,
#                             200.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 67,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "-",
#                         "boundingBox": [
#                             567.0,
#                             192.0,
#                             569.0,
#                             192.0,
#                             569.0,
#                             200.0,
#                             567.0,
#                             200.0
#                         ],
#                         "confidence": 0.691,
#                         "span": {
#                             "offset": 70,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "10:00",
#                         "boundingBox": [
#                             570.0,
#                             192.0,
#                             585.0,
#                             193.0,
#                             584.0,
#                             200.0,
#                             570.0,
#                             200.0
#                         ],
#                         "confidence": 0.885,
#                         "span": {
#                             "offset": 72,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             586.0,
#                             193.0,
#                             593.0,
#                             194.0,
#                             593.0,
#                             200.0,
#                             586.0,
#                             200.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 78,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Aaron",
#                         "boundingBox": [
#                             545.0,
#                             202.0,
#                             560.0,
#                             202.0,
#                             559.0,
#                             208.0,
#                             544.0,
#                             208.0
#                         ],
#                         "confidence": 0.602,
#                         "span": {
#                             "offset": 81,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Buaion",
#                         "boundingBox": [
#                             561.0,
#                             202.0,
#                             580.0,
#                             202.0,
#                             579.0,
#                             208.0,
#                             560.0,
#                             208.0
#                         ],
#                         "confidence": 0.291,
#                         "span": {
#                             "offset": 87,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Daily",
#                         "boundingBox": [
#                             538.0,
#                             259.0,
#                             551.0,
#                             260.0,
#                             550.0,
#                             266.0,
#                             538.0,
#                             265.0
#                         ],
#                         "confidence": 0.175,
#                         "span": {
#                             "offset": 94,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "SCRUM",
#                         "boundingBox": [
#                             552.0,
#                             260.0,
#                             570.0,
#                             260.0,
#                             570.0,
#                             266.0,
#                             551.0,
#                             266.0
#                         ],
#                         "confidence": 0.114,
#                         "span": {
#                             "offset": 100,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "10:00",
#                         "boundingBox": [
#                             539.0,
#                             267.0,
#                             553.0,
#                             267.0,
#                             552.0,
#                             273.0,
#                             538.0,
#                             272.0
#                         ],
#                         "confidence": 0.857,
#                         "span": {
#                             "offset": 106,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             554.0,
#                             267.0,
#                             561.0,
#                             267.0,
#                             560.0,
#                             273.0,
#                             553.0,
#                             273.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 112,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "11:00",
#                         "boundingBox": [
#                             564.0,
#                             267.0,
#                             578.0,
#                             267.0,
#                             577.0,
#                             273.0,
#                             563.0,
#                             273.0
#                         ],
#                         "confidence": 0.479,
#                         "span": {
#                             "offset": 115,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             579.0,
#                             267.0,
#                             586.0,
#                             267.0,
#                             585.0,
#                             273.0,
#                             578.0,
#                             273.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 121,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Churlette",
#                         "boundingBox": [
#                             539.0,
#                             274.0,
#                             562.0,
#                             274.0,
#                             561.0,
#                             279.0,
#                             538.0,
#                             279.0
#                         ],
#                         "confidence": 0.464,
#                         "span": {
#                             "offset": 124,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "de",
#                         "boundingBox": [
#                             563.0,
#                             274.0,
#                             569.0,
#                             274.0,
#                             568.0,
#                             279.0,
#                             562.0,
#                             279.0
#                         ],
#                         "confidence": 0.81,
#                         "span": {
#                             "offset": 134,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Crum",
#                         "boundingBox": [
#                             570.0,
#                             274.0,
#                             582.0,
#                             273.0,
#                             581.0,
#                             279.0,
#                             569.0,
#                             279.0
#                         ],
#                         "confidence": 0.885,
#                         "span": {
#                             "offset": 137,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Quarterly",
#                         "boundingBox": [
#                             540.0,
#                             296.0,
#                             562.0,
#                             296.0,
#                             562.0,
#                             302.0,
#                             539.0,
#                             302.0
#                         ],
#                         "confidence": 0.523,
#                         "span": {
#                             "offset": 142,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "NI",
#                         "boundingBox": [
#                             563.0,
#                             296.0,
#                             570.0,
#                             296.0,
#                             570.0,
#                             302.0,
#                             563.0,
#                             302.0
#                         ],
#                         "confidence": 0.303,
#                         "span": {
#                             "offset": 152,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Hands",
#                         "boundingBox": [
#                             572.0,
#                             296.0,
#                             588.0,
#                             296.0,
#                             588.0,
#                             302.0,
#                             571.0,
#                             302.0
#                         ],
#                         "confidence": 0.613,
#                         "span": {
#                             "offset": 155,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "11.00",
#                         "boundingBox": [
#                             538.0,
#                             304.0,
#                             552.0,
#                             304.0,
#                             552.0,
#                             310.0,
#                             538.0,
#                             310.0
#                         ],
#                         "confidence": 0.618,
#                         "span": {
#                             "offset": 161,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM-12:00",
#                         "boundingBox": [
#                             554.0,
#                             304.0,
#                             578.0,
#                             304.0,
#                             577.0,
#                             310.0,
#                             553.0,
#                             310.0
#                         ],
#                         "confidence": 0.27,
#                         "span": {
#                             "offset": 167,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "PM",
#                         "boundingBox": [
#                             579.0,
#                             304.0,
#                             586.0,
#                             304.0,
#                             586.0,
#                             309.0,
#                             578.0,
#                             310.0
#                         ],
#                         "confidence": 0.662,
#                         "span": {
#                             "offset": 176,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Bebek",
#                         "boundingBox": [
#                             539.0,
#                             310.0,
#                             554.0,
#                             310.0,
#                             554.0,
#                             317.0,
#                             539.0,
#                             316.0
#                         ],
#                         "confidence": 0.611,
#                         "span": {
#                             "offset": 179,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Shaman",
#                         "boundingBox": [
#                             555.0,
#                             310.0,
#                             576.0,
#                             311.0,
#                             576.0,
#                             317.0,
#                             555.0,
#                             317.0
#                         ],
#                         "confidence": 0.605,
#                         "span": {
#                             "offset": 185,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Weekly",
#                         "boundingBox": [
#                             538.0,
#                             332.0,
#                             557.0,
#                             333.0,
#                             556.0,
#                             339.0,
#                             538.0,
#                             338.0
#                         ],
#                         "confidence": 0.606,
#                         "span": {
#                             "offset": 192,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "stand",
#                         "boundingBox": [
#                             558.0,
#                             333.0,
#                             572.0,
#                             334.0,
#                             571.0,
#                             340.0,
#                             557.0,
#                             339.0
#                         ],
#                         "confidence": 0.489,
#                         "span": {
#                             "offset": 199,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "up",
#                         "boundingBox": [
#                             574.0,
#                             334.0,
#                             580.0,
#                             334.0,
#                             580.0,
#                             340.0,
#                             573.0,
#                             340.0
#                         ],
#                         "confidence": 0.815,
#                         "span": {
#                             "offset": 205,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "12:00",
#                         "boundingBox": [
#                             539.0,
#                             341.0,
#                             553.0,
#                             341.0,
#                             552.0,
#                             347.0,
#                             538.0,
#                             347.0
#                         ],
#                         "confidence": 0.826,
#                         "span": {
#                             "offset": 208,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "PM-1:00",
#                         "boundingBox": [
#                             554.0,
#                             341.0,
#                             575.0,
#                             341.0,
#                             574.0,
#                             347.0,
#                             553.0,
#                             347.0
#                         ],
#                         "confidence": 0.209,
#                         "span": {
#                             "offset": 214,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "PM",
#                         "boundingBox": [
#                             576.0,
#                             341.0,
#                             583.0,
#                             341.0,
#                             582.0,
#                             347.0,
#                             575.0,
#                             347.0
#                         ],
#                         "confidence": 0.039,
#                         "span": {
#                             "offset": 222,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Delle",
#                         "boundingBox": [
#                             540.0,
#                             348.0,
#                             559.0,
#                             347.0,
#                             558.0,
#                             353.0,
#                             539.0,
#                             353.0
#                         ],
#                         "confidence": 0.58,
#                         "span": {
#                             "offset": 225,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Marckre",
#                         "boundingBox": [
#                             560.0,
#                             347.0,
#                             582.0,
#                             348.0,
#                             582.0,
#                             353.0,
#                             559.0,
#                             353.0
#                         ],
#                         "confidence": 0.275,
#                         "span": {
#                             "offset": 231,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "Product",
#                         "boundingBox": [
#                             539.0,
#                             370.0,
#                             559.0,
#                             371.0,
#                             558.0,
#                             376.0,
#                             539.0,
#                             376.0
#                         ],
#                         "confidence": 0.615,
#                         "span": {
#                             "offset": 239,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "review",
#                         "boundingBox": [
#                             560.0,
#                             371.0,
#                             576.0,
#                             371.0,
#                             575.0,
#                             376.0,
#                             559.0,
#                             376.0
#                         ],
#                         "confidence": 0.04,
#                         "span": {
#                             "offset": 247,
#                             "length": 6
#                         }
#                     }
#                 ],
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 253
#                     }
#                 ],
#                 "lines": [
#                     {
#                         "content": "9:35 AM",
#                         "boundingBox": [
#                             130.0,
#                             129.0,
#                             215.0,
#                             130.0,
#                             215.0,
#                             149.0,
#                             130.0,
#                             148.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 0,
#                                 "length": 7
#                             }
#                         ]
#                     },
#                     {
#                         "content": "E Conference room 154584354",
#                         "boundingBox": [
#                             130.0,
#                             153.0,
#                             224.0,
#                             154.0,
#                             224.0,
#                             161.0,
#                             130.0,
#                             161.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 8,
#                                 "length": 27
#                             }
#                         ]
#                     },
#                     {
#                         "content": "#: 555-173-4547",
#                         "boundingBox": [
#                             130.0,
#                             163.0,
#                             182.0,
#                             164.0,
#                             181.0,
#                             171.0,
#                             130.0,
#                             170.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 36,
#                                 "length": 15
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Town Hall",
#                         "boundingBox": [
#                             546.0,
#                             180.0,
#                             590.0,
#                             180.0,
#                             590.0,
#                             190.0,
#                             546.0,
#                             190.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 52,
#                                 "length": 9
#                             }
#                         ]
#                     },
#                     {
#                         "content": "9:00 AM - 10:00 AM",
#                         "boundingBox": [
#                             546.0,
#                             191.0,
#                             596.0,
#                             192.0,
#                             596.0,
#                             200.0,
#                             546.0,
#                             199.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 62,
#                                 "length": 18
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Aaron Buaion",
#                         "boundingBox": [
#                             543.0,
#                             201.0,
#                             581.0,
#                             201.0,
#                             581.0,
#                             208.0,
#                             543.0,
#                             208.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 81,
#                                 "length": 12
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Daily SCRUM",
#                         "boundingBox": [
#                             537.0,
#                             259.0,
#                             575.0,
#                             260.0,
#                             575.0,
#                             266.0,
#                             537.0,
#                             265.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 94,
#                                 "length": 11
#                             }
#                         ]
#                     },
#                     {
#                         "content": "10:00 AM 11:00 AM",
#                         "boundingBox": [
#                             536.0,
#                             266.0,
#                             590.0,
#                             266.0,
#                             590.0,
#                             272.0,
#                             536.0,
#                             272.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 106,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Churlette de Crum",
#                         "boundingBox": [
#                             538.0,
#                             273.0,
#                             584.0,
#                             273.0,
#                             585.0,
#                             279.0,
#                             538.0,
#                             279.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 124,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Quarterly NI Hands",
#                         "boundingBox": [
#                             538.0,
#                             295.0,
#                             588.0,
#                             295.0,
#                             588.0,
#                             301.0,
#                             538.0,
#                             302.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 142,
#                                 "length": 18
#                             }
#                         ]
#                     },
#                     {
#                         "content": "11.00 AM-12:00 PM",
#                         "boundingBox": [
#                             536.0,
#                             304.0,
#                             588.0,
#                             303.0,
#                             588.0,
#                             309.0,
#                             536.0,
#                             310.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 161,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Bebek Shaman",
#                         "boundingBox": [
#                             538.0,
#                             310.0,
#                             577.0,
#                             310.0,
#                             577.0,
#                             316.0,
#                             538.0,
#                             316.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 179,
#                                 "length": 12
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Weekly stand up",
#                         "boundingBox": [
#                             537.0,
#                             332.0,
#                             582.0,
#                             333.0,
#                             582.0,
#                             339.0,
#                             537.0,
#                             338.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 192,
#                                 "length": 15
#                             }
#                         ]
#                     },
#                     {
#                         "content": "12:00 PM-1:00 PM",
#                         "boundingBox": [
#                             537.0,
#                             340.0,
#                             583.0,
#                             340.0,
#                             583.0,
#                             347.0,
#                             536.0,
#                             346.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 208,
#                                 "length": 16
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Delle Marckre",
#                         "boundingBox": [
#                             538.0,
#                             347.0,
#                             582.0,
#                             347.0,
#                             582.0,
#                             352.0,
#                             538.0,
#                             353.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 225,
#                                 "length": 13
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Product review",
#                         "boundingBox": [
#                             538.0,
#                             370.0,
#                             577.0,
#                             370.0,
#                             577.0,
#                             376.0,
#                             538.0,
#                             375.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 239,
#                                 "length": 14
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "styles": [],
#         "modelVersion": "2022-04-30"
#     },
#     "denseCaptionsResult": {
#         "values": [
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 1038,
#                     "h": 692
#                 }
#             },
#             {
#                 "text": "a screen shot of a computer",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 62,
#                     "y": 51,
#                     "w": 673,
#                     "h": 437
#                 }
#             },
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 646,
#                     "y": 63,
#                     "w": 269,
#                     "h": 605
#                 }
#             },
#             {
#                 "text": "a close up of a table",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 536,
#                     "w": 1021,
#                     "h": 146
#                 }
#             },
#             {
#                 "text": "a close up of a man's head",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 782,
#                     "y": 77,
#                     "w": 116,
#                     "h": 103
#                 }
#             },
#             {
#                 "text": "a person's back pocket",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 753,
#                     "y": 538,
#                     "w": 140,
#                     "h": 135
#                 }
#             },
#             {
#                 "text": "a close up of a plant",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 10,
#                     "w": 86,
#                     "h": 507
#                 }
#             },
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 9,
#                     "y": 15,
#                     "w": 973,
#                     "h": 651
#                 }
#             },
#             {
#                 "text": "a person in a yellow coat",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 687,
#                     "y": 199,
#                     "w": 225,
#                     "h": 356
#                 }
#             },
#             {
#                 "text": "a screen shot of a phone",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 215,
#                     "h": 541
#                 }
#             }
#         ]
#     },
#     "modelVersion": "2023-02-01-preview",
#     "metadata": {
#         "width": 1038,
#         "height": 692
#     },
#     "tagsResult": {
#         "values": [
#             {
#                 "name": "text",
#                 "confidence": 0.9966012239456177
#             },
#             {
#                 "name": "clothing",
#                 "confidence": 0.9801060557365417
#             },
#             {
#                 "name": "person",
#                 "confidence": 0.9596296548843384
#             },
#             {
#                 "name": "display device",
#                 "confidence": 0.9490274786949158
#             },
#             {
#                 "name": "indoor",
#                 "confidence": 0.947483241558075
#             },
#             {
#                 "name": "wall",
#                 "confidence": 0.9395941495895386
#             },
#             {
#                 "name": "media",
#                 "confidence": 0.9306115508079529
#             },
#             {
#                 "name": "television set",
#                 "confidence": 0.9280922412872314
#             },
#             {
#                 "name": "led-backlit lcd display",
#                 "confidence": 0.9254804849624634
#             },
#             {
#                 "name": "flat panel display",
#                 "confidence": 0.9209464192390442
#             },
#             {
#                 "name": "furniture",
#                 "confidence": 0.9132548570632935
#             },
#             {
#                 "name": "lcd tv",
#                 "confidence": 0.895058274269104
#             },
#             {
#                 "name": "man",
#                 "confidence": 0.8883916735649109
#             },
#             {
#                 "name": "television",
#                 "confidence": 0.8766454458236694
#             },
#             {
#                 "name": "video",
#                 "confidence": 0.8746980428695679
#             },
#             {
#                 "name": "multimedia",
#                 "confidence": 0.8719364404678345
#             },
#             {
#                 "name": "output device",
#                 "confidence": 0.8585700988769531
#             },
#             {
#                 "name": "computer monitor",
#                 "confidence": 0.844162106513977
#             },
#             {
#                 "name": "table",
#                 "confidence": 0.8429560661315918
#             },
#             {
#                 "name": "screen",
#                 "confidence": 0.7113153338432312
#             },
#             {
#                 "name": "standing",
#                 "confidence": 0.7051211595535278
#             },
#             {
#                 "name": "design",
#                 "confidence": 0.40424615144729614
#             }
#         ]
#     },
#     "smartCropsResult": {
#         "values": [
#             {
#                 "aspectRatio": 1.09,
#                 "boundingBox": {
#                     "x": 303,
#                     "y": 29,
#                     "w": 692,
#                     "h": 634
#                 }
#             }
#         ]
#     },
#     "peopleResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 659,
#                     "y": 82,
#                     "w": 256,
#                     "h": 594
#                 },
#                 "confidence": 0.9592611193656921
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 1,
#                     "w": 200,
#                     "h": 507
#                 },
#                 "confidence": 0.00403070030733943
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 7,
#                     "w": 69,
#                     "h": 509
#                 },
#                 "confidence": 0.0024984374176710844
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 203,
#                     "h": 141
#                 },
#                 "confidence": 0.001100298948585987
#             }
#         ]
#     }
# }

# %%
pprintjson(results)
# Out:
# {
#     "captionResult": {
#         "text": "a man pointing at a screen",
#         "confidence": 1.0
#     },
#     "objectsResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 655,
#                     "y": 83,
#                     "w": 263,
#                     "h": 605
#                 },
#                 "tags": [
#                     {
#                         "name": "person",
#                         "confidence": 0.905
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 75,
#                     "y": 76,
#                     "w": 678,
#                     "h": 414
#                 },
#                 "tags": [
#                     {
#                         "name": "television",
#                         "confidence": 0.808
#                     }
#                 ]
#             }
#         ]
#     },
#     "readResult": {
#         "stringIndexType": "TextElements",
#         "content": "9:35 AM\nE Conference room 154584354\n#: 555-173-4547\nTown Hall\n9:00 AM - 10:00 AM\nAaron Buaion\nDaily SCRUM\n10:00 AM 11:00 AM\nChurlette de Crum\nQuarterly NI Hands\n11.00 AM-12:00 PM\nBebek Shaman\nWeekly stand up\n12:00 PM-1:00 PM\nDelle Marckre\nProduct review",
#         "pages": [
#             {
#                 "height": 692.0,
#                 "width": 1038.0,
#                 "angle": 0.3048,
#                 "pageNumber": 1,
#                 "words": [
#                     {
#                         "content": "9:35",
#                         "boundingBox": [
#                             131.0,
#                             130.0,
#                             171.0,
#                             130.0,
#                             171.0,
#                             149.0,
#                             130.0,
#                             149.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 0,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             179.0,
#                             130.0,
#                             204.0,
#                             130.0,
#                             203.0,
#                             149.0,
#                             178.0,
#                             149.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 5,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "E",
#                         "boundingBox": [
#                             131.0,
#                             154.0,
#                             135.0,
#                             154.0,
#                             135.0,
#                             161.0,
#                             131.0,
#                             161.0
#                         ],
#                         "confidence": 0.104,
#                         "span": {
#                             "offset": 8,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "Conference",
#                         "boundingBox": [
#                             142.0,
#                             154.0,
#                             174.0,
#                             154.0,
#                             173.0,
#                             161.0,
#                             141.0,
#                             161.0
#                         ],
#                         "confidence": 0.902,
#                         "span": {
#                             "offset": 10,
#                             "length": 10
#                         }
#                     },
#                     {
#                         "content": "room",
#                         "boundingBox": [
#                             175.0,
#                             154.0,
#                             189.0,
#                             155.0,
#                             188.0,
#                             161.0,
#                             175.0,
#                             161.0
#                         ],
#                         "confidence": 0.796,
#                         "span": {
#                             "offset": 21,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "154584354",
#                         "boundingBox": [
#                             192.0,
#                             155.0,
#                             224.0,
#                             154.0,
#                             223.0,
#                             162.0,
#                             191.0,
#                             161.0
#                         ],
#                         "confidence": 0.864,
#                         "span": {
#                             "offset": 26,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "#:",
#                         "boundingBox": [
#                             131.0,
#                             163.0,
#                             139.0,
#                             164.0,
#                             139.0,
#                             171.0,
#                             131.0,
#                             171.0
#                         ],
#                         "confidence": 0.036,
#                         "span": {
#                             "offset": 36,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "555-173-4547",
#                         "boundingBox": [
#                             142.0,
#                             164.0,
#                             182.0,
#                             165.0,
#                             181.0,
#                             171.0,
#                             142.0,
#                             171.0
#                         ],
#                         "confidence": 0.597,
#                         "span": {
#                             "offset": 39,
#                             "length": 12
#                         }
#                     },
#                     {
#                         "content": "Town",
#                         "boundingBox": [
#                             547.0,
#                             181.0,
#                             568.0,
#                             181.0,
#                             568.0,
#                             190.0,
#                             546.0,
#                             191.0
#                         ],
#                         "confidence": 0.981,
#                         "span": {
#                             "offset": 52,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Hall",
#                         "boundingBox": [
#                             570.0,
#                             181.0,
#                             590.0,
#                             181.0,
#                             590.0,
#                             191.0,
#                             570.0,
#                             190.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 57,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "9:00",
#                         "boundingBox": [
#                             546.0,
#                             192.0,
#                             555.0,
#                             192.0,
#                             555.0,
#                             200.0,
#                             546.0,
#                             200.0
#                         ],
#                         "confidence": 0.09,
#                         "span": {
#                             "offset": 62,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             557.0,
#                             192.0,
#                             565.0,
#                             192.0,
#                             565.0,
#                             200.0,
#                             557.0,
#                             200.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 67,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "-",
#                         "boundingBox": [
#                             567.0,
#                             192.0,
#                             569.0,
#                             192.0,
#                             569.0,
#                             200.0,
#                             567.0,
#                             200.0
#                         ],
#                         "confidence": 0.691,
#                         "span": {
#                             "offset": 70,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "10:00",
#                         "boundingBox": [
#                             570.0,
#                             192.0,
#                             585.0,
#                             193.0,
#                             584.0,
#                             200.0,
#                             570.0,
#                             200.0
#                         ],
#                         "confidence": 0.885,
#                         "span": {
#                             "offset": 72,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             586.0,
#                             193.0,
#                             593.0,
#                             194.0,
#                             593.0,
#                             200.0,
#                             586.0,
#                             200.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 78,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Aaron",
#                         "boundingBox": [
#                             545.0,
#                             202.0,
#                             560.0,
#                             202.0,
#                             559.0,
#                             208.0,
#                             544.0,
#                             208.0
#                         ],
#                         "confidence": 0.602,
#                         "span": {
#                             "offset": 81,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Buaion",
#                         "boundingBox": [
#                             561.0,
#                             202.0,
#                             580.0,
#                             202.0,
#                             579.0,
#                             208.0,
#                             560.0,
#                             208.0
#                         ],
#                         "confidence": 0.291,
#                         "span": {
#                             "offset": 87,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Daily",
#                         "boundingBox": [
#                             538.0,
#                             259.0,
#                             551.0,
#                             260.0,
#                             550.0,
#                             266.0,
#                             538.0,
#                             265.0
#                         ],
#                         "confidence": 0.175,
#                         "span": {
#                             "offset": 94,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "SCRUM",
#                         "boundingBox": [
#                             552.0,
#                             260.0,
#                             570.0,
#                             260.0,
#                             570.0,
#                             266.0,
#                             551.0,
#                             266.0
#                         ],
#                         "confidence": 0.114,
#                         "span": {
#                             "offset": 100,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "10:00",
#                         "boundingBox": [
#                             539.0,
#                             267.0,
#                             553.0,
#                             267.0,
#                             552.0,
#                             273.0,
#                             538.0,
#                             272.0
#                         ],
#                         "confidence": 0.857,
#                         "span": {
#                             "offset": 106,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             554.0,
#                             267.0,
#                             561.0,
#                             267.0,
#                             560.0,
#                             273.0,
#                             553.0,
#                             273.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 112,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "11:00",
#                         "boundingBox": [
#                             564.0,
#                             267.0,
#                             578.0,
#                             267.0,
#                             577.0,
#                             273.0,
#                             563.0,
#                             273.0
#                         ],
#                         "confidence": 0.479,
#                         "span": {
#                             "offset": 115,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM",
#                         "boundingBox": [
#                             579.0,
#                             267.0,
#                             586.0,
#                             267.0,
#                             585.0,
#                             273.0,
#                             578.0,
#                             273.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 121,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Churlette",
#                         "boundingBox": [
#                             539.0,
#                             274.0,
#                             562.0,
#                             274.0,
#                             561.0,
#                             279.0,
#                             538.0,
#                             279.0
#                         ],
#                         "confidence": 0.464,
#                         "span": {
#                             "offset": 124,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "de",
#                         "boundingBox": [
#                             563.0,
#                             274.0,
#                             569.0,
#                             274.0,
#                             568.0,
#                             279.0,
#                             562.0,
#                             279.0
#                         ],
#                         "confidence": 0.81,
#                         "span": {
#                             "offset": 134,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Crum",
#                         "boundingBox": [
#                             570.0,
#                             274.0,
#                             582.0,
#                             273.0,
#                             581.0,
#                             279.0,
#                             569.0,
#                             279.0
#                         ],
#                         "confidence": 0.885,
#                         "span": {
#                             "offset": 137,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Quarterly",
#                         "boundingBox": [
#                             540.0,
#                             296.0,
#                             562.0,
#                             296.0,
#                             562.0,
#                             302.0,
#                             539.0,
#                             302.0
#                         ],
#                         "confidence": 0.523,
#                         "span": {
#                             "offset": 142,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "NI",
#                         "boundingBox": [
#                             563.0,
#                             296.0,
#                             570.0,
#                             296.0,
#                             570.0,
#                             302.0,
#                             563.0,
#                             302.0
#                         ],
#                         "confidence": 0.303,
#                         "span": {
#                             "offset": 152,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Hands",
#                         "boundingBox": [
#                             572.0,
#                             296.0,
#                             588.0,
#                             296.0,
#                             588.0,
#                             302.0,
#                             571.0,
#                             302.0
#                         ],
#                         "confidence": 0.613,
#                         "span": {
#                             "offset": 155,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "11.00",
#                         "boundingBox": [
#                             538.0,
#                             304.0,
#                             552.0,
#                             304.0,
#                             552.0,
#                             310.0,
#                             538.0,
#                             310.0
#                         ],
#                         "confidence": 0.618,
#                         "span": {
#                             "offset": 161,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "AM-12:00",
#                         "boundingBox": [
#                             554.0,
#                             304.0,
#                             578.0,
#                             304.0,
#                             577.0,
#                             310.0,
#                             553.0,
#                             310.0
#                         ],
#                         "confidence": 0.27,
#                         "span": {
#                             "offset": 167,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "PM",
#                         "boundingBox": [
#                             579.0,
#                             304.0,
#                             586.0,
#                             304.0,
#                             586.0,
#                             309.0,
#                             578.0,
#                             310.0
#                         ],
#                         "confidence": 0.662,
#                         "span": {
#                             "offset": 176,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Bebek",
#                         "boundingBox": [
#                             539.0,
#                             310.0,
#                             554.0,
#                             310.0,
#                             554.0,
#                             317.0,
#                             539.0,
#                             316.0
#                         ],
#                         "confidence": 0.611,
#                         "span": {
#                             "offset": 179,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Shaman",
#                         "boundingBox": [
#                             555.0,
#                             310.0,
#                             576.0,
#                             311.0,
#                             576.0,
#                             317.0,
#                             555.0,
#                             317.0
#                         ],
#                         "confidence": 0.605,
#                         "span": {
#                             "offset": 185,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Weekly",
#                         "boundingBox": [
#                             538.0,
#                             332.0,
#                             557.0,
#                             333.0,
#                             556.0,
#                             339.0,
#                             538.0,
#                             338.0
#                         ],
#                         "confidence": 0.606,
#                         "span": {
#                             "offset": 192,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "stand",
#                         "boundingBox": [
#                             558.0,
#                             333.0,
#                             572.0,
#                             334.0,
#                             571.0,
#                             340.0,
#                             557.0,
#                             339.0
#                         ],
#                         "confidence": 0.489,
#                         "span": {
#                             "offset": 199,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "up",
#                         "boundingBox": [
#                             574.0,
#                             334.0,
#                             580.0,
#                             334.0,
#                             580.0,
#                             340.0,
#                             573.0,
#                             340.0
#                         ],
#                         "confidence": 0.815,
#                         "span": {
#                             "offset": 205,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "12:00",
#                         "boundingBox": [
#                             539.0,
#                             341.0,
#                             553.0,
#                             341.0,
#                             552.0,
#                             347.0,
#                             538.0,
#                             347.0
#                         ],
#                         "confidence": 0.826,
#                         "span": {
#                             "offset": 208,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "PM-1:00",
#                         "boundingBox": [
#                             554.0,
#                             341.0,
#                             575.0,
#                             341.0,
#                             574.0,
#                             347.0,
#                             553.0,
#                             347.0
#                         ],
#                         "confidence": 0.209,
#                         "span": {
#                             "offset": 214,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "PM",
#                         "boundingBox": [
#                             576.0,
#                             341.0,
#                             583.0,
#                             341.0,
#                             582.0,
#                             347.0,
#                             575.0,
#                             347.0
#                         ],
#                         "confidence": 0.039,
#                         "span": {
#                             "offset": 222,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Delle",
#                         "boundingBox": [
#                             540.0,
#                             348.0,
#                             559.0,
#                             347.0,
#                             558.0,
#                             353.0,
#                             539.0,
#                             353.0
#                         ],
#                         "confidence": 0.58,
#                         "span": {
#                             "offset": 225,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Marckre",
#                         "boundingBox": [
#                             560.0,
#                             347.0,
#                             582.0,
#                             348.0,
#                             582.0,
#                             353.0,
#                             559.0,
#                             353.0
#                         ],
#                         "confidence": 0.275,
#                         "span": {
#                             "offset": 231,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "Product",
#                         "boundingBox": [
#                             539.0,
#                             370.0,
#                             559.0,
#                             371.0,
#                             558.0,
#                             376.0,
#                             539.0,
#                             376.0
#                         ],
#                         "confidence": 0.615,
#                         "span": {
#                             "offset": 239,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "review",
#                         "boundingBox": [
#                             560.0,
#                             371.0,
#                             576.0,
#                             371.0,
#                             575.0,
#                             376.0,
#                             559.0,
#                             376.0
#                         ],
#                         "confidence": 0.04,
#                         "span": {
#                             "offset": 247,
#                             "length": 6
#                         }
#                     }
#                 ],
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 253
#                     }
#                 ],
#                 "lines": [
#                     {
#                         "content": "9:35 AM",
#                         "boundingBox": [
#                             130.0,
#                             129.0,
#                             215.0,
#                             130.0,
#                             215.0,
#                             149.0,
#                             130.0,
#                             148.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 0,
#                                 "length": 7
#                             }
#                         ]
#                     },
#                     {
#                         "content": "E Conference room 154584354",
#                         "boundingBox": [
#                             130.0,
#                             153.0,
#                             224.0,
#                             154.0,
#                             224.0,
#                             161.0,
#                             130.0,
#                             161.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 8,
#                                 "length": 27
#                             }
#                         ]
#                     },
#                     {
#                         "content": "#: 555-173-4547",
#                         "boundingBox": [
#                             130.0,
#                             163.0,
#                             182.0,
#                             164.0,
#                             181.0,
#                             171.0,
#                             130.0,
#                             170.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 36,
#                                 "length": 15
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Town Hall",
#                         "boundingBox": [
#                             546.0,
#                             180.0,
#                             590.0,
#                             180.0,
#                             590.0,
#                             190.0,
#                             546.0,
#                             190.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 52,
#                                 "length": 9
#                             }
#                         ]
#                     },
#                     {
#                         "content": "9:00 AM - 10:00 AM",
#                         "boundingBox": [
#                             546.0,
#                             191.0,
#                             596.0,
#                             192.0,
#                             596.0,
#                             200.0,
#                             546.0,
#                             199.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 62,
#                                 "length": 18
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Aaron Buaion",
#                         "boundingBox": [
#                             543.0,
#                             201.0,
#                             581.0,
#                             201.0,
#                             581.0,
#                             208.0,
#                             543.0,
#                             208.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 81,
#                                 "length": 12
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Daily SCRUM",
#                         "boundingBox": [
#                             537.0,
#                             259.0,
#                             575.0,
#                             260.0,
#                             575.0,
#                             266.0,
#                             537.0,
#                             265.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 94,
#                                 "length": 11
#                             }
#                         ]
#                     },
#                     {
#                         "content": "10:00 AM 11:00 AM",
#                         "boundingBox": [
#                             536.0,
#                             266.0,
#                             590.0,
#                             266.0,
#                             590.0,
#                             272.0,
#                             536.0,
#                             272.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 106,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Churlette de Crum",
#                         "boundingBox": [
#                             538.0,
#                             273.0,
#                             584.0,
#                             273.0,
#                             585.0,
#                             279.0,
#                             538.0,
#                             279.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 124,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Quarterly NI Hands",
#                         "boundingBox": [
#                             538.0,
#                             295.0,
#                             588.0,
#                             295.0,
#                             588.0,
#                             301.0,
#                             538.0,
#                             302.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 142,
#                                 "length": 18
#                             }
#                         ]
#                     },
#                     {
#                         "content": "11.00 AM-12:00 PM",
#                         "boundingBox": [
#                             536.0,
#                             304.0,
#                             588.0,
#                             303.0,
#                             588.0,
#                             309.0,
#                             536.0,
#                             310.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 161,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Bebek Shaman",
#                         "boundingBox": [
#                             538.0,
#                             310.0,
#                             577.0,
#                             310.0,
#                             577.0,
#                             316.0,
#                             538.0,
#                             316.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 179,
#                                 "length": 12
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Weekly stand up",
#                         "boundingBox": [
#                             537.0,
#                             332.0,
#                             582.0,
#                             333.0,
#                             582.0,
#                             339.0,
#                             537.0,
#                             338.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 192,
#                                 "length": 15
#                             }
#                         ]
#                     },
#                     {
#                         "content": "12:00 PM-1:00 PM",
#                         "boundingBox": [
#                             537.0,
#                             340.0,
#                             583.0,
#                             340.0,
#                             583.0,
#                             347.0,
#                             536.0,
#                             346.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 208,
#                                 "length": 16
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Delle Marckre",
#                         "boundingBox": [
#                             538.0,
#                             347.0,
#                             582.0,
#                             347.0,
#                             582.0,
#                             352.0,
#                             538.0,
#                             353.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 225,
#                                 "length": 13
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Product review",
#                         "boundingBox": [
#                             538.0,
#                             370.0,
#                             577.0,
#                             370.0,
#                             577.0,
#                             376.0,
#                             538.0,
#                             375.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 239,
#                                 "length": 14
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "styles": [],
#         "modelVersion": "2022-04-30"
#     },
#     "denseCaptionsResult": {
#         "values": [
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 1038,
#                     "h": 692
#                 }
#             },
#             {
#                 "text": "a screen shot of a computer",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 62,
#                     "y": 51,
#                     "w": 673,
#                     "h": 437
#                 }
#             },
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 646,
#                     "y": 63,
#                     "w": 269,
#                     "h": 605
#                 }
#             },
#             {
#                 "text": "a close up of a table",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 536,
#                     "w": 1021,
#                     "h": 146
#                 }
#             },
#             {
#                 "text": "a close up of a man's head",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 782,
#                     "y": 77,
#                     "w": 116,
#                     "h": 103
#                 }
#             },
#             {
#                 "text": "a person's back pocket",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 753,
#                     "y": 538,
#                     "w": 140,
#                     "h": 135
#                 }
#             },
#             {
#                 "text": "a close up of a plant",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 10,
#                     "w": 86,
#                     "h": 507
#                 }
#             },
#             {
#                 "text": "a man pointing at a screen",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 9,
#                     "y": 15,
#                     "w": 973,
#                     "h": 651
#                 }
#             },
#             {
#                 "text": "a person in a yellow coat",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 687,
#                     "y": 199,
#                     "w": 225,
#                     "h": 356
#                 }
#             },
#             {
#                 "text": "a screen shot of a phone",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 215,
#                     "h": 541
#                 }
#             }
#         ]
#     },
#     "modelVersion": "2023-02-01-preview",
#     "metadata": {
#         "width": 1038,
#         "height": 692
#     },
#     "tagsResult": {
#         "values": [
#             {
#                 "name": "text",
#                 "confidence": 0.9966012239456177
#             },
#             {
#                 "name": "clothing",
#                 "confidence": 0.9801060557365417
#             },
#             {
#                 "name": "person",
#                 "confidence": 0.9596296548843384
#             },
#             {
#                 "name": "display device",
#                 "confidence": 0.9490274786949158
#             },
#             {
#                 "name": "indoor",
#                 "confidence": 0.947483241558075
#             },
#             {
#                 "name": "wall",
#                 "confidence": 0.9395941495895386
#             },
#             {
#                 "name": "media",
#                 "confidence": 0.9306115508079529
#             },
#             {
#                 "name": "television set",
#                 "confidence": 0.9280922412872314
#             },
#             {
#                 "name": "led-backlit lcd display",
#                 "confidence": 0.9254804849624634
#             },
#             {
#                 "name": "flat panel display",
#                 "confidence": 0.9209464192390442
#             },
#             {
#                 "name": "furniture",
#                 "confidence": 0.9132548570632935
#             },
#             {
#                 "name": "lcd tv",
#                 "confidence": 0.895058274269104
#             },
#             {
#                 "name": "man",
#                 "confidence": 0.8883916735649109
#             },
#             {
#                 "name": "television",
#                 "confidence": 0.8766454458236694
#             },
#             {
#                 "name": "video",
#                 "confidence": 0.8746980428695679
#             },
#             {
#                 "name": "multimedia",
#                 "confidence": 0.8719364404678345
#             },
#             {
#                 "name": "output device",
#                 "confidence": 0.8585700988769531
#             },
#             {
#                 "name": "computer monitor",
#                 "confidence": 0.844162106513977
#             },
#             {
#                 "name": "table",
#                 "confidence": 0.8429560661315918
#             },
#             {
#                 "name": "screen",
#                 "confidence": 0.7113153338432312
#             },
#             {
#                 "name": "standing",
#                 "confidence": 0.7051211595535278
#             },
#             {
#                 "name": "design",
#                 "confidence": 0.40424615144729614
#             }
#         ]
#     },
#     "smartCropsResult": {
#         "values": [
#             {
#                 "aspectRatio": 1.09,
#                 "boundingBox": {
#                     "x": 303,
#                     "y": 29,
#                     "w": 692,
#                     "h": 634
#                 }
#             }
#         ]
#     },
#     "peopleResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 659,
#                     "y": 82,
#                     "w": 256,
#                     "h": 594
#                 },
#                 "confidence": 0.9592611193656921
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 1,
#                     "w": 200,
#                     "h": 507
#                 },
#                 "confidence": 0.00403070030733943
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 7,
#                     "w": 69,
#                     "h": 509
#                 },
#                 "confidence": 0.0024984374176710844
#             },
#             {
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 203,
#                     "h": 141
#                 },
#                 "confidence": 0.001100298948585987
#             }
#         ]
#     }
# }

# %%
pprintjson(results["modelVersion"])
# Out:
# "2023-02-01-preview"

# %%
pprintjson(results["metadata"])
# Out:
# {
#     "width": 1038,
#     "height": 692
# }

# %%
pprintjson(results["captionResult"])
# Out:
# {
#     "text": "a man pointing at a screen",
#     "confidence": 1.0
# }

# %%
pprintjson(results["objectsResult"])
# Out:
# {
#     "values": [
#         {
#             "boundingBox": {
#                 "x": 655,
#                 "y": 83,
#                 "w": 263,
#                 "h": 605
#             },
#             "tags": [
#                 {
#                     "name": "person",
#                     "confidence": 0.905
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 75,
#                 "y": 76,
#                 "w": 678,
#                 "h": 414
#             },
#             "tags": [
#                 {
#                     "name": "television",
#                     "confidence": 0.808
#                 }
#             ]
#         }
#     ]
# }

# %%
pprintjson(results["denseCaptionsResult"])
# Out:
# {
#     "values": [
#         {
#             "text": "a man pointing at a screen",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 0,
#                 "y": 0,
#                 "w": 1038,
#                 "h": 692
#             }
#         },
#         {
#             "text": "a screen shot of a computer",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 62,
#                 "y": 51,
#                 "w": 673,
#                 "h": 437
#             }
#         },
#         {
#             "text": "a man pointing at a screen",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 646,
#                 "y": 63,
#                 "w": 269,
#                 "h": 605
#             }
#         },
#         {
#             "text": "a close up of a table",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 0,
#                 "y": 536,
#                 "w": 1021,
#                 "h": 146
#             }
#         },
#         {
#             "text": "a close up of a man's head",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 782,
#                 "y": 77,
#                 "w": 116,
#                 "h": 103
#             }
#         },
#         {
#             "text": "a person's back pocket",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 753,
#                 "y": 538,
#                 "w": 140,
#                 "h": 135
#             }
#         },
#         {
#             "text": "a close up of a plant",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 0,
#                 "y": 10,
#                 "w": 86,
#                 "h": 507
#             }
#         },
#         {
#             "text": "a man pointing at a screen",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 9,
#                 "y": 15,
#                 "w": 973,
#                 "h": 651
#             }
#         },
#         {
#             "text": "a person in a yellow coat",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 687,
#                 "y": 199,
#                 "w": 225,
#                 "h": 356
#             }
#         },
#         {
#             "text": "a screen shot of a phone",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 0,
#                 "y": 0,
#                 "w": 215,
#                 "h": 541
#             }
#         }
#     ]
# }

# %%
pprintjson(results["tagsResult"])
# Out:
# {
#     "values": [
#         {
#             "name": "text",
#             "confidence": 0.9966012239456177
#         },
#         {
#             "name": "clothing",
#             "confidence": 0.9801060557365417
#         },
#         {
#             "name": "person",
#             "confidence": 0.9596296548843384
#         },
#         {
#             "name": "display device",
#             "confidence": 0.9490274786949158
#         },
#         {
#             "name": "indoor",
#             "confidence": 0.947483241558075
#         },
#         {
#             "name": "wall",
#             "confidence": 0.9395941495895386
#         },
#         {
#             "name": "media",
#             "confidence": 0.9306115508079529
#         },
#         {
#             "name": "television set",
#             "confidence": 0.9280922412872314
#         },
#         {
#             "name": "led-backlit lcd display",
#             "confidence": 0.9254804849624634
#         },
#         {
#             "name": "flat panel display",
#             "confidence": 0.9209464192390442
#         },
#         {
#             "name": "furniture",
#             "confidence": 0.9132548570632935
#         },
#         {
#             "name": "lcd tv",
#             "confidence": 0.895058274269104
#         },
#         {
#             "name": "man",
#             "confidence": 0.8883916735649109
#         },
#         {
#             "name": "television",
#             "confidence": 0.8766454458236694
#         },
#         {
#             "name": "video",
#             "confidence": 0.8746980428695679
#         },
#         {
#             "name": "multimedia",
#             "confidence": 0.8719364404678345
#         },
#         {
#             "name": "output device",
#             "confidence": 0.8585700988769531
#         },
#         {
#             "name": "computer monitor",
#             "confidence": 0.844162106513977
#         },
#         {
#             "name": "table",
#             "confidence": 0.8429560661315918
#         },
#         {
#             "name": "screen",
#             "confidence": 0.7113153338432312
#         },
#         {
#             "name": "standing",
#             "confidence": 0.7051211595535278
#         },
#         {
#             "name": "design",
#             "confidence": 0.40424615144729614
#         }
#     ]
# }

# %%
pprintjson(results["readResult"])
# Out:
# {
#     "stringIndexType": "TextElements",
#     "content": "9:35 AM\nE Conference room 154584354\n#: 555-173-4547\nTown Hall\n9:00 AM - 10:00 AM\nAaron Buaion\nDaily SCRUM\n10:00 AM 11:00 AM\nChurlette de Crum\nQuarterly NI Hands\n11.00 AM-12:00 PM\nBebek Shaman\nWeekly stand up\n12:00 PM-1:00 PM\nDelle Marckre\nProduct review",
#     "pages": [
#         {
#             "height": 692.0,
#             "width": 1038.0,
#             "angle": 0.3048,
#             "pageNumber": 1,
#             "words": [
#                 {
#                     "content": "9:35",
#                     "boundingBox": [
#                         131.0,
#                         130.0,
#                         171.0,
#                         130.0,
#                         171.0,
#                         149.0,
#                         130.0,
#                         149.0
#                     ],
#                     "confidence": 0.993,
#                     "span": {
#                         "offset": 0,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "AM",
#                     "boundingBox": [
#                         179.0,
#                         130.0,
#                         204.0,
#                         130.0,
#                         203.0,
#                         149.0,
#                         178.0,
#                         149.0
#                     ],
#                     "confidence": 0.998,
#                     "span": {
#                         "offset": 5,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "E",
#                     "boundingBox": [
#                         131.0,
#                         154.0,
#                         135.0,
#                         154.0,
#                         135.0,
#                         161.0,
#                         131.0,
#                         161.0
#                     ],
#                     "confidence": 0.104,
#                     "span": {
#                         "offset": 8,
#                         "length": 1
#                     }
#                 },
#                 {
#                     "content": "Conference",
#                     "boundingBox": [
#                         142.0,
#                         154.0,
#                         174.0,
#                         154.0,
#                         173.0,
#                         161.0,
#                         141.0,
#                         161.0
#                     ],
#                     "confidence": 0.902,
#                     "span": {
#                         "offset": 10,
#                         "length": 10
#                     }
#                 },
#                 {
#                     "content": "room",
#                     "boundingBox": [
#                         175.0,
#                         154.0,
#                         189.0,
#                         155.0,
#                         188.0,
#                         161.0,
#                         175.0,
#                         161.0
#                     ],
#                     "confidence": 0.796,
#                     "span": {
#                         "offset": 21,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "154584354",
#                     "boundingBox": [
#                         192.0,
#                         155.0,
#                         224.0,
#                         154.0,
#                         223.0,
#                         162.0,
#                         191.0,
#                         161.0
#                     ],
#                     "confidence": 0.864,
#                     "span": {
#                         "offset": 26,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "#:",
#                     "boundingBox": [
#                         131.0,
#                         163.0,
#                         139.0,
#                         164.0,
#                         139.0,
#                         171.0,
#                         131.0,
#                         171.0
#                     ],
#                     "confidence": 0.036,
#                     "span": {
#                         "offset": 36,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "555-173-4547",
#                     "boundingBox": [
#                         142.0,
#                         164.0,
#                         182.0,
#                         165.0,
#                         181.0,
#                         171.0,
#                         142.0,
#                         171.0
#                     ],
#                     "confidence": 0.597,
#                     "span": {
#                         "offset": 39,
#                         "length": 12
#                     }
#                 },
#                 {
#                     "content": "Town",
#                     "boundingBox": [
#                         547.0,
#                         181.0,
#                         568.0,
#                         181.0,
#                         568.0,
#                         190.0,
#                         546.0,
#                         191.0
#                     ],
#                     "confidence": 0.981,
#                     "span": {
#                         "offset": 52,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Hall",
#                     "boundingBox": [
#                         570.0,
#                         181.0,
#                         590.0,
#                         181.0,
#                         590.0,
#                         191.0,
#                         570.0,
#                         190.0
#                     ],
#                     "confidence": 0.991,
#                     "span": {
#                         "offset": 57,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "9:00",
#                     "boundingBox": [
#                         546.0,
#                         192.0,
#                         555.0,
#                         192.0,
#                         555.0,
#                         200.0,
#                         546.0,
#                         200.0
#                     ],
#                     "confidence": 0.09,
#                     "span": {
#                         "offset": 62,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "AM",
#                     "boundingBox": [
#                         557.0,
#                         192.0,
#                         565.0,
#                         192.0,
#                         565.0,
#                         200.0,
#                         557.0,
#                         200.0
#                     ],
#                     "confidence": 0.991,
#                     "span": {
#                         "offset": 67,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "-",
#                     "boundingBox": [
#                         567.0,
#                         192.0,
#                         569.0,
#                         192.0,
#                         569.0,
#                         200.0,
#                         567.0,
#                         200.0
#                     ],
#                     "confidence": 0.691,
#                     "span": {
#                         "offset": 70,
#                         "length": 1
#                     }
#                 },
#                 {
#                     "content": "10:00",
#                     "boundingBox": [
#                         570.0,
#                         192.0,
#                         585.0,
#                         193.0,
#                         584.0,
#                         200.0,
#                         570.0,
#                         200.0
#                     ],
#                     "confidence": 0.885,
#                     "span": {
#                         "offset": 72,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "AM",
#                     "boundingBox": [
#                         586.0,
#                         193.0,
#                         593.0,
#                         194.0,
#                         593.0,
#                         200.0,
#                         586.0,
#                         200.0
#                     ],
#                     "confidence": 0.991,
#                     "span": {
#                         "offset": 78,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Aaron",
#                     "boundingBox": [
#                         545.0,
#                         202.0,
#                         560.0,
#                         202.0,
#                         559.0,
#                         208.0,
#                         544.0,
#                         208.0
#                     ],
#                     "confidence": 0.602,
#                     "span": {
#                         "offset": 81,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Buaion",
#                     "boundingBox": [
#                         561.0,
#                         202.0,
#                         580.0,
#                         202.0,
#                         579.0,
#                         208.0,
#                         560.0,
#                         208.0
#                     ],
#                     "confidence": 0.291,
#                     "span": {
#                         "offset": 87,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Daily",
#                     "boundingBox": [
#                         538.0,
#                         259.0,
#                         551.0,
#                         260.0,
#                         550.0,
#                         266.0,
#                         538.0,
#                         265.0
#                     ],
#                     "confidence": 0.175,
#                     "span": {
#                         "offset": 94,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "SCRUM",
#                     "boundingBox": [
#                         552.0,
#                         260.0,
#                         570.0,
#                         260.0,
#                         570.0,
#                         266.0,
#                         551.0,
#                         266.0
#                     ],
#                     "confidence": 0.114,
#                     "span": {
#                         "offset": 100,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "10:00",
#                     "boundingBox": [
#                         539.0,
#                         267.0,
#                         553.0,
#                         267.0,
#                         552.0,
#                         273.0,
#                         538.0,
#                         272.0
#                     ],
#                     "confidence": 0.857,
#                     "span": {
#                         "offset": 106,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "AM",
#                     "boundingBox": [
#                         554.0,
#                         267.0,
#                         561.0,
#                         267.0,
#                         560.0,
#                         273.0,
#                         553.0,
#                         273.0
#                     ],
#                     "confidence": 0.998,
#                     "span": {
#                         "offset": 112,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "11:00",
#                     "boundingBox": [
#                         564.0,
#                         267.0,
#                         578.0,
#                         267.0,
#                         577.0,
#                         273.0,
#                         563.0,
#                         273.0
#                     ],
#                     "confidence": 0.479,
#                     "span": {
#                         "offset": 115,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "AM",
#                     "boundingBox": [
#                         579.0,
#                         267.0,
#                         586.0,
#                         267.0,
#                         585.0,
#                         273.0,
#                         578.0,
#                         273.0
#                     ],
#                     "confidence": 0.994,
#                     "span": {
#                         "offset": 121,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Churlette",
#                     "boundingBox": [
#                         539.0,
#                         274.0,
#                         562.0,
#                         274.0,
#                         561.0,
#                         279.0,
#                         538.0,
#                         279.0
#                     ],
#                     "confidence": 0.464,
#                     "span": {
#                         "offset": 124,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "de",
#                     "boundingBox": [
#                         563.0,
#                         274.0,
#                         569.0,
#                         274.0,
#                         568.0,
#                         279.0,
#                         562.0,
#                         279.0
#                     ],
#                     "confidence": 0.81,
#                     "span": {
#                         "offset": 134,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Crum",
#                     "boundingBox": [
#                         570.0,
#                         274.0,
#                         582.0,
#                         273.0,
#                         581.0,
#                         279.0,
#                         569.0,
#                         279.0
#                     ],
#                     "confidence": 0.885,
#                     "span": {
#                         "offset": 137,
#                         "length": 4
#                     }
#                 },
#                 {
#                     "content": "Quarterly",
#                     "boundingBox": [
#                         540.0,
#                         296.0,
#                         562.0,
#                         296.0,
#                         562.0,
#                         302.0,
#                         539.0,
#                         302.0
#                     ],
#                     "confidence": 0.523,
#                     "span": {
#                         "offset": 142,
#                         "length": 9
#                     }
#                 },
#                 {
#                     "content": "NI",
#                     "boundingBox": [
#                         563.0,
#                         296.0,
#                         570.0,
#                         296.0,
#                         570.0,
#                         302.0,
#                         563.0,
#                         302.0
#                     ],
#                     "confidence": 0.303,
#                     "span": {
#                         "offset": 152,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Hands",
#                     "boundingBox": [
#                         572.0,
#                         296.0,
#                         588.0,
#                         296.0,
#                         588.0,
#                         302.0,
#                         571.0,
#                         302.0
#                     ],
#                     "confidence": 0.613,
#                     "span": {
#                         "offset": 155,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "11.00",
#                     "boundingBox": [
#                         538.0,
#                         304.0,
#                         552.0,
#                         304.0,
#                         552.0,
#                         310.0,
#                         538.0,
#                         310.0
#                     ],
#                     "confidence": 0.618,
#                     "span": {
#                         "offset": 161,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "AM-12:00",
#                     "boundingBox": [
#                         554.0,
#                         304.0,
#                         578.0,
#                         304.0,
#                         577.0,
#                         310.0,
#                         553.0,
#                         310.0
#                     ],
#                     "confidence": 0.27,
#                     "span": {
#                         "offset": 167,
#                         "length": 8
#                     }
#                 },
#                 {
#                     "content": "PM",
#                     "boundingBox": [
#                         579.0,
#                         304.0,
#                         586.0,
#                         304.0,
#                         586.0,
#                         309.0,
#                         578.0,
#                         310.0
#                     ],
#                     "confidence": 0.662,
#                     "span": {
#                         "offset": 176,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Bebek",
#                     "boundingBox": [
#                         539.0,
#                         310.0,
#                         554.0,
#                         310.0,
#                         554.0,
#                         317.0,
#                         539.0,
#                         316.0
#                     ],
#                     "confidence": 0.611,
#                     "span": {
#                         "offset": 179,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Shaman",
#                     "boundingBox": [
#                         555.0,
#                         310.0,
#                         576.0,
#                         311.0,
#                         576.0,
#                         317.0,
#                         555.0,
#                         317.0
#                     ],
#                     "confidence": 0.605,
#                     "span": {
#                         "offset": 185,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "Weekly",
#                     "boundingBox": [
#                         538.0,
#                         332.0,
#                         557.0,
#                         333.0,
#                         556.0,
#                         339.0,
#                         538.0,
#                         338.0
#                     ],
#                     "confidence": 0.606,
#                     "span": {
#                         "offset": 192,
#                         "length": 6
#                     }
#                 },
#                 {
#                     "content": "stand",
#                     "boundingBox": [
#                         558.0,
#                         333.0,
#                         572.0,
#                         334.0,
#                         571.0,
#                         340.0,
#                         557.0,
#                         339.0
#                     ],
#                     "confidence": 0.489,
#                     "span": {
#                         "offset": 199,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "up",
#                     "boundingBox": [
#                         574.0,
#                         334.0,
#                         580.0,
#                         334.0,
#                         580.0,
#                         340.0,
#                         573.0,
#                         340.0
#                     ],
#                     "confidence": 0.815,
#                     "span": {
#                         "offset": 205,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "12:00",
#                     "boundingBox": [
#                         539.0,
#                         341.0,
#                         553.0,
#                         341.0,
#                         552.0,
#                         347.0,
#                         538.0,
#                         347.0
#                     ],
#                     "confidence": 0.826,
#                     "span": {
#                         "offset": 208,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "PM-1:00",
#                     "boundingBox": [
#                         554.0,
#                         341.0,
#                         575.0,
#                         341.0,
#                         574.0,
#                         347.0,
#                         553.0,
#                         347.0
#                     ],
#                     "confidence": 0.209,
#                     "span": {
#                         "offset": 214,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "PM",
#                     "boundingBox": [
#                         576.0,
#                         341.0,
#                         583.0,
#                         341.0,
#                         582.0,
#                         347.0,
#                         575.0,
#                         347.0
#                     ],
#                     "confidence": 0.039,
#                     "span": {
#                         "offset": 222,
#                         "length": 2
#                     }
#                 },
#                 {
#                     "content": "Delle",
#                     "boundingBox": [
#                         540.0,
#                         348.0,
#                         559.0,
#                         347.0,
#                         558.0,
#                         353.0,
#                         539.0,
#                         353.0
#                     ],
#                     "confidence": 0.58,
#                     "span": {
#                         "offset": 225,
#                         "length": 5
#                     }
#                 },
#                 {
#                     "content": "Marckre",
#                     "boundingBox": [
#                         560.0,
#                         347.0,
#                         582.0,
#                         348.0,
#                         582.0,
#                         353.0,
#                         559.0,
#                         353.0
#                     ],
#                     "confidence": 0.275,
#                     "span": {
#                         "offset": 231,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "Product",
#                     "boundingBox": [
#                         539.0,
#                         370.0,
#                         559.0,
#                         371.0,
#                         558.0,
#                         376.0,
#                         539.0,
#                         376.0
#                     ],
#                     "confidence": 0.615,
#                     "span": {
#                         "offset": 239,
#                         "length": 7
#                     }
#                 },
#                 {
#                     "content": "review",
#                     "boundingBox": [
#                         560.0,
#                         371.0,
#                         576.0,
#                         371.0,
#                         575.0,
#                         376.0,
#                         559.0,
#                         376.0
#                     ],
#                     "confidence": 0.04,
#                     "span": {
#                         "offset": 247,
#                         "length": 6
#                     }
#                 }
#             ],
#             "spans": [
#                 {
#                     "offset": 0,
#                     "length": 253
#                 }
#             ],
#             "lines": [
#                 {
#                     "content": "9:35 AM",
#                     "boundingBox": [
#                         130.0,
#                         129.0,
#                         215.0,
#                         130.0,
#                         215.0,
#                         149.0,
#                         130.0,
#                         148.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "E Conference room 154584354",
#                     "boundingBox": [
#                         130.0,
#                         153.0,
#                         224.0,
#                         154.0,
#                         224.0,
#                         161.0,
#                         130.0,
#                         161.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 8,
#                             "length": 27
#                         }
#                     ]
#                 },
#                 {
#                     "content": "#: 555-173-4547",
#                     "boundingBox": [
#                         130.0,
#                         163.0,
#                         182.0,
#                         164.0,
#                         181.0,
#                         171.0,
#                         130.0,
#                         170.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 36,
#                             "length": 15
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Town Hall",
#                     "boundingBox": [
#                         546.0,
#                         180.0,
#                         590.0,
#                         180.0,
#                         590.0,
#                         190.0,
#                         546.0,
#                         190.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 52,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 {
#                     "content": "9:00 AM - 10:00 AM",
#                     "boundingBox": [
#                         546.0,
#                         191.0,
#                         596.0,
#                         192.0,
#                         596.0,
#                         200.0,
#                         546.0,
#                         199.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 62,
#                             "length": 18
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Aaron Buaion",
#                     "boundingBox": [
#                         543.0,
#                         201.0,
#                         581.0,
#                         201.0,
#                         581.0,
#                         208.0,
#                         543.0,
#                         208.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 81,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Daily SCRUM",
#                     "boundingBox": [
#                         537.0,
#                         259.0,
#                         575.0,
#                         260.0,
#                         575.0,
#                         266.0,
#                         537.0,
#                         265.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 94,
#                             "length": 11
#                         }
#                     ]
#                 },
#                 {
#                     "content": "10:00 AM 11:00 AM",
#                     "boundingBox": [
#                         536.0,
#                         266.0,
#                         590.0,
#                         266.0,
#                         590.0,
#                         272.0,
#                         536.0,
#                         272.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 106,
#                             "length": 17
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Churlette de Crum",
#                     "boundingBox": [
#                         538.0,
#                         273.0,
#                         584.0,
#                         273.0,
#                         585.0,
#                         279.0,
#                         538.0,
#                         279.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 124,
#                             "length": 17
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Quarterly NI Hands",
#                     "boundingBox": [
#                         538.0,
#                         295.0,
#                         588.0,
#                         295.0,
#                         588.0,
#                         301.0,
#                         538.0,
#                         302.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 142,
#                             "length": 18
#                         }
#                     ]
#                 },
#                 {
#                     "content": "11.00 AM-12:00 PM",
#                     "boundingBox": [
#                         536.0,
#                         304.0,
#                         588.0,
#                         303.0,
#                         588.0,
#                         309.0,
#                         536.0,
#                         310.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 161,
#                             "length": 17
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Bebek Shaman",
#                     "boundingBox": [
#                         538.0,
#                         310.0,
#                         577.0,
#                         310.0,
#                         577.0,
#                         316.0,
#                         538.0,
#                         316.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 179,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Weekly stand up",
#                     "boundingBox": [
#                         537.0,
#                         332.0,
#                         582.0,
#                         333.0,
#                         582.0,
#                         339.0,
#                         537.0,
#                         338.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 192,
#                             "length": 15
#                         }
#                     ]
#                 },
#                 {
#                     "content": "12:00 PM-1:00 PM",
#                     "boundingBox": [
#                         537.0,
#                         340.0,
#                         583.0,
#                         340.0,
#                         583.0,
#                         347.0,
#                         536.0,
#                         346.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 208,
#                             "length": 16
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Delle Marckre",
#                     "boundingBox": [
#                         538.0,
#                         347.0,
#                         582.0,
#                         347.0,
#                         582.0,
#                         352.0,
#                         538.0,
#                         353.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 225,
#                             "length": 13
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Product review",
#                     "boundingBox": [
#                         538.0,
#                         370.0,
#                         577.0,
#                         370.0,
#                         577.0,
#                         376.0,
#                         538.0,
#                         375.0
#                     ],
#                     "spans": [
#                         {
#                             "offset": 239,
#                             "length": 14
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     "styles": [],
#     "modelVersion": "2022-04-30"
# }

# %%
pprintjson(results["readResult"]["content"])
# Out:
# "9:35 AM\nE Conference room 154584354\n#: 555-173-4547\nTown Hall\n9:00 AM - 10:00 AM\nAaron Buaion\nDaily SCRUM\n10:00 AM 11:00 AM\nChurlette de Crum\nQuarterly NI Hands\n11.00 AM-12:00 PM\nBebek Shaman\nWeekly stand up\n12:00 PM-1:00 PM\nDelle Marckre\nProduct review"

# %%
pprintjson(results["smartCropsResult"])
# Out:
# {
#     "values": [
#         {
#             "aspectRatio": 1.09,
#             "boundingBox": {
#                 "x": 303,
#                 "y": 29,
#                 "w": 692,
#                 "h": 634
#             }
#         }
#     ]
# }

# %%
pprintjson(results["peopleResult"])
# Out:
# {
#     "values": [
#         {
#             "boundingBox": {
#                 "x": 659,
#                 "y": 82,
#                 "w": 256,
#                 "h": 594
#             },
#             "confidence": 0.9592611193656921
#         },
#         {
#             "boundingBox": {
#                 "x": 0,
#                 "y": 1,
#                 "w": 200,
#                 "h": 507
#             },
#             "confidence": 0.00403070030733943
#         },
#         {
#             "boundingBox": {
#                 "x": 0,
#                 "y": 7,
#                 "w": 69,
#                 "h": 509
#             },
#             "confidence": 0.0024984374176710844
#         },
#         {
#             "boundingBox": {
#                 "x": 0,
#                 "y": 0,
#                 "w": 203,
#                 "h": 141
#             },
#             "confidence": 0.001100298948585987
#         }
#     ]
# }

# %% [markdown]
# ## Test 2

# %%
image_file = os.path.join(IMAGES_DIR, "postalcard.jpg")

img = Image.open(image_file)
img.thumbnail((640, 640), Image.LANCZOS)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640>

# %%
with open(image_file, "rb") as f:
    data = f.read()

r = requests.post(url, data=data, headers=headers)

results = r.json()
pprintjson(results)
# Out:
# {
#     "captionResult": {
#         "text": "a white paper with black writing on it",
#         "confidence": 1.0
#     },
#     "objectsResult": {
#         "values": []
#     },
#     "readResult": {
#         "stringIndexType": "TextElements",
#         "content": "A person who drinks a lot of tea.\nGlasgow Banter Range | Ref: PC002\nMade in the UK\nWelcome to\nGlasgow !\nIt's an amazing city\nand a friendly place\n- I hope you have\na great time here\nand come to love\n@ Lesley Williamson | www.lesleywilliamson.com\nit as wel\nRobert",
#         "pages": [
#             {
#                 "height": 800.0,
#                 "width": 600.0,
#                 "angle": 5.3622,
#                 "pageNumber": 1,
#                 "words": [
#                     {
#                         "content": "A",
#                         "boundingBox": [
#                             207.0,
#                             124.0,
#                             210.0,
#                             124.0,
#                             210.0,
#                             133.0,
#                             207.0,
#                             133.0
#                         ],
#                         "confidence": 0.927,
#                         "span": {
#                             "offset": 0,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "person",
#                         "boundingBox": [
#                             212.0,
#                             124.0,
#                             241.0,
#                             124.0,
#                             241.0,
#                             134.0,
#                             212.0,
#                             133.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 2,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "who",
#                         "boundingBox": [
#                             243.0,
#                             124.0,
#                             261.0,
#                             125.0,
#                             261.0,
#                             134.0,
#                             243.0,
#                             134.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 9,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "drinks",
#                         "boundingBox": [
#                             263.0,
#                             125.0,
#                             288.0,
#                             126.0,
#                             288.0,
#                             135.0,
#                             263.0,
#                             134.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 13,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "a",
#                         "boundingBox": [
#                             290.0,
#                             126.0,
#                             296.0,
#                             126.0,
#                             295.0,
#                             135.0,
#                             290.0,
#                             135.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 20,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "lot",
#                         "boundingBox": [
#                             298.0,
#                             126.0,
#                             309.0,
#                             126.0,
#                             309.0,
#                             136.0,
#                             298.0,
#                             135.0
#                         ],
#                         "confidence": 0.78,
#                         "span": {
#                             "offset": 22,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "of",
#                         "boundingBox": [
#                             311.0,
#                             126.0,
#                             320.0,
#                             127.0,
#                             319.0,
#                             136.0,
#                             311.0,
#                             136.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 26,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "tea.",
#                         "boundingBox": [
#                             322.0,
#                             127.0,
#                             338.0,
#                             128.0,
#                             337.0,
#                             137.0,
#                             321.0,
#                             136.0
#                         ],
#                         "confidence": 0.751,
#                         "span": {
#                             "offset": 29,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Glasgow",
#                         "boundingBox": [
#                             206.0,
#                             132.0,
#                             238.0,
#                             133.0,
#                             237.0,
#                             142.0,
#                             205.0,
#                             141.0
#                         ],
#                         "confidence": 0.556,
#                         "span": {
#                             "offset": 34,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "Banter",
#                         "boundingBox": [
#                             241.0,
#                             133.0,
#                             269.0,
#                             134.0,
#                             269.0,
#                             144.0,
#                             241.0,
#                             143.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 42,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Range",
#                         "boundingBox": [
#                             271.0,
#                             134.0,
#                             299.0,
#                             135.0,
#                             299.0,
#                             145.0,
#                             271.0,
#                             144.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 49,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "|",
#                         "boundingBox": [
#                             301.0,
#                             135.0,
#                             305.0,
#                             135.0,
#                             305.0,
#                             145.0,
#                             301.0,
#                             145.0
#                         ],
#                         "confidence": 0.942,
#                         "span": {
#                             "offset": 55,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "Ref:",
#                         "boundingBox": [
#                             306.0,
#                             135.0,
#                             324.0,
#                             135.0,
#                             324.0,
#                             146.0,
#                             306.0,
#                             145.0
#                         ],
#                         "confidence": 0.811,
#                         "span": {
#                             "offset": 57,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "PC002",
#                         "boundingBox": [
#                             326.0,
#                             136.0,
#                             356.0,
#                             136.0,
#                             357.0,
#                             147.0,
#                             326.0,
#                             146.0
#                         ],
#                         "confidence": 0.933,
#                         "span": {
#                             "offset": 62,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Made",
#                         "boundingBox": [
#                             202.0,
#                             141.0,
#                             225.0,
#                             142.0,
#                             225.0,
#                             151.0,
#                             201.0,
#                             151.0
#                         ],
#                         "confidence": 0.981,
#                         "span": {
#                             "offset": 68,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "in",
#                         "boundingBox": [
#                             227.0,
#                             142.0,
#                             235.0,
#                             142.0,
#                             234.0,
#                             151.0,
#                             226.0,
#                             151.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 73,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "the",
#                         "boundingBox": [
#                             237.0,
#                             142.0,
#                             251.0,
#                             143.0,
#                             250.0,
#                             152.0,
#                             236.0,
#                             152.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 76,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "UK",
#                         "boundingBox": [
#                             253.0,
#                             143.0,
#                             265.0,
#                             144.0,
#                             265.0,
#                             153.0,
#                             252.0,
#                             152.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 80,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Welcome",
#                         "boundingBox": [
#                             192.0,
#                             182.0,
#                             344.0,
#                             191.0,
#                             342.0,
#                             222.0,
#                             189.0,
#                             214.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 83,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "to",
#                         "boundingBox": [
#                             361.0,
#                             192.0,
#                             396.0,
#                             194.0,
#                             394.0,
#                             224.0,
#                             359.0,
#                             223.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 91,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Glasgow",
#                         "boundingBox": [
#                             193.0,
#                             222.0,
#                             313.0,
#                             234.0,
#                             311.0,
#                             274.0,
#                             189.0,
#                             266.0
#                         ],
#                         "confidence": 0.939,
#                         "span": {
#                             "offset": 94,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "!",
#                         "boundingBox": [
#                             322.0,
#                             235.0,
#                             334.0,
#                             236.0,
#                             332.0,
#                             275.0,
#                             320.0,
#                             275.0
#                         ],
#                         "confidence": 0.967,
#                         "span": {
#                             "offset": 102,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "It's",
#                         "boundingBox": [
#                             174.0,
#                             303.0,
#                             221.0,
#                             307.0,
#                             218.0,
#                             335.0,
#                             171.0,
#                             329.0
#                         ],
#                         "confidence": 0.986,
#                         "span": {
#                             "offset": 104,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "an",
#                         "boundingBox": [
#                             237.0,
#                             308.0,
#                             272.0,
#                             311.0,
#                             269.0,
#                             341.0,
#                             234.0,
#                             337.0
#                         ],
#                         "confidence": 0.961,
#                         "span": {
#                             "offset": 109,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "amazing",
#                         "boundingBox": [
#                             284.0,
#                             312.0,
#                             395.0,
#                             322.0,
#                             393.0,
#                             353.0,
#                             281.0,
#                             342.0
#                         ],
#                         "confidence": 0.8,
#                         "span": {
#                             "offset": 112,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "city",
#                         "boundingBox": [
#                             401.0,
#                             323.0,
#                             447.0,
#                             327.0,
#                             445.0,
#                             357.0,
#                             399.0,
#                             354.0
#                         ],
#                         "confidence": 0.943,
#                         "span": {
#                             "offset": 120,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "and",
#                         "boundingBox": [
#                             155.0,
#                             350.0,
#                             202.0,
#                             354.0,
#                             200.0,
#                             381.0,
#                             153.0,
#                             376.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 125,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "a",
#                         "boundingBox": [
#                             214.0,
#                             355.0,
#                             232.0,
#                             357.0,
#                             229.0,
#                             384.0,
#                             212.0,
#                             382.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 129,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "friendly",
#                         "boundingBox": [
#                             247.0,
#                             358.0,
#                             330.0,
#                             365.0,
#                             327.0,
#                             394.0,
#                             244.0,
#                             386.0
#                         ],
#                         "confidence": 0.984,
#                         "span": {
#                             "offset": 131,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "place",
#                         "boundingBox": [
#                             352.0,
#                             367.0,
#                             414.0,
#                             372.0,
#                             411.0,
#                             401.0,
#                             350.0,
#                             396.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 140,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "-",
#                         "boundingBox": [
#                             146.0,
#                             400.0,
#                             163.0,
#                             402.0,
#                             160.0,
#                             426.0,
#                             143.0,
#                             423.0
#                         ],
#                         "confidence": 0.886,
#                         "span": {
#                             "offset": 146,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "I",
#                         "boundingBox": [
#                             174.0,
#                             404.0,
#                             191.0,
#                             406.0,
#                             188.0,
#                             432.0,
#                             171.0,
#                             428.0
#                         ],
#                         "confidence": 0.834,
#                         "span": {
#                             "offset": 148,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "hope",
#                         "boundingBox": [
#                             206.0,
#                             408.0,
#                             261.0,
#                             416.0,
#                             258.0,
#                             444.0,
#                             202.0,
#                             434.0
#                         ],
#                         "confidence": 0.98,
#                         "span": {
#                             "offset": 150,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "you",
#                         "boundingBox": [
#                             289.0,
#                             420.0,
#                             334.0,
#                             427.0,
#                             331.0,
#                             455.0,
#                             286.0,
#                             448.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 155,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "have",
#                         "boundingBox": [
#                             366.0,
#                             432.0,
#                             421.0,
#                             441.0,
#                             418.0,
#                             467.0,
#                             363.0,
#                             459.0
#                         ],
#                         "confidence": 0.909,
#                         "span": {
#                             "offset": 159,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "a",
#                         "boundingBox": [
#                             139.0,
#                             459.0,
#                             154.0,
#                             460.0,
#                             151.0,
#                             488.0,
#                             136.0,
#                             486.0
#                         ],
#                         "confidence": 0.988,
#                         "span": {
#                             "offset": 164,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "great",
#                         "boundingBox": [
#                             173.0,
#                             462.0,
#                             245.0,
#                             470.0,
#                             243.0,
#                             499.0,
#                             170.0,
#                             490.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 166,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "time",
#                         "boundingBox": [
#                             265.0,
#                             472.0,
#                             330.0,
#                             478.0,
#                             327.0,
#                             508.0,
#                             262.0,
#                             501.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 172,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "here",
#                         "boundingBox": [
#                             361.0,
#                             481.0,
#                             417.0,
#                             487.0,
#                             415.0,
#                             517.0,
#                             358.0,
#                             511.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 177,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "and",
#                         "boundingBox": [
#                             133.0,
#                             520.0,
#                             176.0,
#                             526.0,
#                             172.0,
#                             553.0,
#                             129.0,
#                             545.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 182,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "come",
#                         "boundingBox": [
#                             219.0,
#                             533.0,
#                             287.0,
#                             542.0,
#                             284.0,
#                             571.0,
#                             216.0,
#                             560.0
#                         ],
#                         "confidence": 0.645,
#                         "span": {
#                             "offset": 186,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "to",
#                         "boundingBox": [
#                             302.0,
#                             544.0,
#                             334.0,
#                             548.0,
#                             331.0,
#                             577.0,
#                             299.0,
#                             573.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 191,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "love",
#                         "boundingBox": [
#                             360.0,
#                             551.0,
#                             421.0,
#                             558.0,
#                             419.0,
#                             586.0,
#                             357.0,
#                             580.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 194,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "@",
#                         "boundingBox": [
#                             474.0,
#                             571.0,
#                             474.0,
#                             564.0,
#                             489.0,
#                             564.0,
#                             489.0,
#                             572.0
#                         ],
#                         "confidence": 0.011,
#                         "span": {
#                             "offset": 199,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "Lesley",
#                         "boundingBox": [
#                             474.0,
#                             560.0,
#                             475.0,
#                             524.0,
#                             490.0,
#                             524.0,
#                             489.0,
#                             560.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 201,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Williamson",
#                         "boundingBox": [
#                             475.0,
#                             521.0,
#                             477.0,
#                             465.0,
#                             491.0,
#                             464.0,
#                             490.0,
#                             521.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 208,
#                             "length": 10
#                         }
#                     },
#                     {
#                         "content": "|",
#                         "boundingBox": [
#                             477.0,
#                             462.0,
#                             477.0,
#                             458.0,
#                             491.0,
#                             458.0,
#                             491.0,
#                             462.0
#                         ],
#                         "confidence": 0.941,
#                         "span": {
#                             "offset": 219,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "www.lesleywilliamson.com",
#                         "boundingBox": [
#                             477.0,
#                             455.0,
#                             479.0,
#                             333.0,
#                             492.0,
#                             332.0,
#                             491.0,
#                             455.0
#                         ],
#                         "confidence": 0.941,
#                         "span": {
#                             "offset": 221,
#                             "length": 24
#                         }
#                     },
#                     {
#                         "content": "it",
#                         "boundingBox": [
#                             137.0,
#                             575.0,
#                             165.0,
#                             580.0,
#                             161.0,
#                             609.0,
#                             134.0,
#                             604.0
#                         ],
#                         "confidence": 0.943,
#                         "span": {
#                             "offset": 246,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "as",
#                         "boundingBox": [
#                             196.0,
#                             586.0,
#                             235.0,
#                             592.0,
#                             231.0,
#                             622.0,
#                             193.0,
#                             615.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 249,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "wel",
#                         "boundingBox": [
#                             286.0,
#                             599.0,
#                             332.0,
#                             604.0,
#                             330.0,
#                             635.0,
#                             283.0,
#                             630.0
#                         ],
#                         "confidence": 0.108,
#                         "span": {
#                             "offset": 252,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "Robert",
#                         "boundingBox": [
#                             128.0,
#                             649.0,
#                             235.0,
#                             674.0,
#                             228.0,
#                             705.0,
#                             121.0,
#                             681.0
#                         ],
#                         "confidence": 0.989,
#                         "span": {
#                             "offset": 256,
#                             "length": 6
#                         }
#                     }
#                 ],
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 262
#                     }
#                 ],
#                 "lines": [
#                     {
#                         "content": "A person who drinks a lot of tea.",
#                         "boundingBox": [
#                             206.0,
#                             123.0,
#                             337.0,
#                             127.0,
#                             337.0,
#                             136.0,
#                             206.0,
#                             132.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 0,
#                                 "length": 33
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Glasgow Banter Range | Ref: PC002",
#                         "boundingBox": [
#                             205.0,
#                             132.0,
#                             359.0,
#                             136.0,
#                             359.0,
#                             146.0,
#                             205.0,
#                             141.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 34,
#                                 "length": 33
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Made in the UK",
#                         "boundingBox": [
#                             201.0,
#                             140.0,
#                             269.0,
#                             143.0,
#                             269.0,
#                             153.0,
#                             201.0,
#                             150.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 68,
#                                 "length": 14
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Welcome to",
#                         "boundingBox": [
#                             190.0,
#                             181.0,
#                             398.0,
#                             192.0,
#                             396.0,
#                             224.0,
#                             188.0,
#                             213.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 83,
#                                 "length": 10
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Glasgow !",
#                         "boundingBox": [
#                             192.0,
#                             222.0,
#                             334.0,
#                             233.0,
#                             331.0,
#                             275.0,
#                             188.0,
#                             265.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 94,
#                                 "length": 9
#                             }
#                         ]
#                     },
#                     {
#                         "content": "It's an amazing city",
#                         "boundingBox": [
#                             173.0,
#                             302.0,
#                             450.0,
#                             327.0,
#                             447.0,
#                             358.0,
#                             170.0,
#                             331.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 104,
#                                 "length": 20
#                             }
#                         ]
#                     },
#                     {
#                         "content": "and a friendly place",
#                         "boundingBox": [
#                             155.0,
#                             350.0,
#                             413.0,
#                             371.0,
#                             411.0,
#                             400.0,
#                             152.0,
#                             377.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 125,
#                                 "length": 20
#                             }
#                         ]
#                     },
#                     {
#                         "content": "- I hope you have",
#                         "boundingBox": [
#                             146.0,
#                             400.0,
#                             424.0,
#                             440.0,
#                             420.0,
#                             467.0,
#                             142.0,
#                             425.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 146,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "a great time here",
#                         "boundingBox": [
#                             138.0,
#                             458.0,
#                             420.0,
#                             486.0,
#                             417.0,
#                             517.0,
#                             135.0,
#                             487.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 164,
#                                 "length": 17
#                             }
#                         ]
#                     },
#                     {
#                         "content": "and come to love",
#                         "boundingBox": [
#                             132.0,
#                             519.0,
#                             424.0,
#                             558.0,
#                             420.0,
#                             587.0,
#                             128.0,
#                             548.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 182,
#                                 "length": 16
#                             }
#                         ]
#                     },
#                     {
#                         "content": "@ Lesley Williamson | www.lesleywilliamson.com",
#                         "boundingBox": [
#                             474.0,
#                             573.0,
#                             478.0,
#                             328.0,
#                             492.0,
#                             328.0,
#                             488.0,
#                             573.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 199,
#                                 "length": 46
#                             }
#                         ]
#                     },
#                     {
#                         "content": "it as wel",
#                         "boundingBox": [
#                             137.0,
#                             575.0,
#                             333.0,
#                             604.0,
#                             329.0,
#                             635.0,
#                             133.0,
#                             605.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 246,
#                                 "length": 9
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Robert",
#                         "boundingBox": [
#                             123.0,
#                             647.0,
#                             237.0,
#                             674.0,
#                             230.0,
#                             705.0,
#                             116.0,
#                             679.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 256,
#                                 "length": 6
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "styles": [
#             {
#                 "isHandwritten": true,
#                 "spans": [
#                     {
#                         "offset": 104,
#                         "length": 94
#                     },
#                     {
#                         "offset": 246,
#                         "length": 16
#                     }
#                 ],
#                 "confidence": 1.0
#             }
#         ],
#         "modelVersion": "2022-04-30"
#     },
#     "denseCaptionsResult": {
#         "values": [
#             {
#                 "text": "a white paper with black writing on it",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 600,
#                     "h": 800
#                 }
#             },
#             {
#                 "text": "a white paper with black writing on it",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 51,
#                     "y": 99,
#                     "w": 535,
#                     "h": 669
#                 }
#             }
#         ]
#     },
#     "modelVersion": "2023-02-01-preview",
#     "metadata": {
#         "width": 600,
#         "height": 800
#     },
#     "tagsResult": {
#         "values": [
#             {
#                 "name": "text",
#                 "confidence": 0.9999737739562988
#             },
#             {
#                 "name": "receipt",
#                 "confidence": 0.9936124086380005
#             },
#             {
#                 "name": "handwriting",
#                 "confidence": 0.9765975475311279
#             }
#         ]
#     },
#     "smartCropsResult": {
#         "values": [
#             {
#                 "aspectRatio": 0.61,
#                 "boundingBox": {
#                     "x": 75,
#                     "y": 33,
#                     "w": 450,
#                     "h": 734
#                 }
#             }
#         ]
#     },
#     "peopleResult": {
#         "values": []
#     }
# }

# %%
print(results["readResult"]["content"])
# Out:
# A person who drinks a lot of tea.
# Glasgow Banter Range | Ref: PC002
# Made in the UK
# Welcome to
# Glasgow !
# It's an amazing city
# and a friendly place
# - I hope you have
# a great time here
# and come to love
# @ Lesley Williamson | www.lesleywilliamson.com
# it as wel
# Robert

# %% [markdown]
# ## Test 3

# %%
image_file = os.path.join(IMAGES_DIR, "businesscard.jpg")

img = Image.open(image_file)
img.thumbnail((640, 640), Image.LANCZOS)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=427x640>

# %%
with open(image_file, "rb") as f:
    data = f.read()

r = requests.post(url, data=data, headers=headers)

results = r.json()
pprintjson(results)
# Out:
# {
#     "captionResult": {
#         "text": "a business card on a table",
#         "confidence": 1.0
#     },
#     "objectsResult": {
#         "values": []
#     },
#     "readResult": {
#         "stringIndexType": "TextElements",
#         "content": "John Doe\nJohn.Doe@microsoft.com\nhttp://www.microsoft.com/taiwan\nSoftware Development Engineer\nMicrosoft Al Research and\nMain\n+886 2 3725 3888\nDevelopment Center, Taiwan\nFax\n+886 2 3725 3999\nCustomer Service Center\n00801 128 000\nMicrosoft Taiwan Corporation\n18F ., No. 68, Sec. 5, Zhongxiao E. Rd .,\nXinyi Dist ., Taipei 11065,\nMicrosoft\nTaiwan, R.O.C.",
#         "pages": [
#             {
#                 "height": 1632.0,
#                 "width": 2448.0,
#                 "angle": 0.1305,
#                 "pageNumber": 1,
#                 "words": [
#                     {
#                         "content": "John",
#                         "boundingBox": [
#                             280.0,
#                             186.0,
#                             497.0,
#                             190.0,
#                             496.0,
#                             272.0,
#                             279.0,
#                             269.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 0,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Doe",
#                         "boundingBox": [
#                             536.0,
#                             191.0,
#                             728.0,
#                             193.0,
#                             728.0,
#                             274.0,
#                             536.0,
#                             272.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 5,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "John.Doe@microsoft.com",
#                         "boundingBox": [
#                             1393.0,
#                             200.0,
#                             1973.0,
#                             206.0,
#                             1974.0,
#                             253.0,
#                             1391.0,
#                             249.0
#                         ],
#                         "confidence": 0.967,
#                         "span": {
#                             "offset": 9,
#                             "length": 22
#                         }
#                     },
#                     {
#                         "content": "http://www.microsoft.com/taiwan",
#                         "boundingBox": [
#                             1394.0,
#                             262.0,
#                             2173.0,
#                             267.0,
#                             2174.0,
#                             315.0,
#                             1394.0,
#                             313.0
#                         ],
#                         "confidence": 0.934,
#                         "span": {
#                             "offset": 32,
#                             "length": 31
#                         }
#                     },
#                     {
#                         "content": "Software",
#                         "boundingBox": [
#                             274.0,
#                             310.0,
#                             499.0,
#                             314.0,
#                             497.0,
#                             370.0,
#                             271.0,
#                             363.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 64,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "Development",
#                         "boundingBox": [
#                             512.0,
#                             314.0,
#                             867.0,
#                             319.0,
#                             867.0,
#                             379.0,
#                             510.0,
#                             371.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 73,
#                             "length": 11
#                         }
#                     },
#                     {
#                         "content": "Engineer",
#                         "boundingBox": [
#                             879.0,
#                             319.0,
#                             1106.0,
#                             323.0,
#                             1108.0,
#                             382.0,
#                             879.0,
#                             379.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 85,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "Microsoft",
#                         "boundingBox": [
#                             267.0,
#                             378.0,
#                             516.0,
#                             380.0,
#                             515.0,
#                             435.0,
#                             265.0,
#                             431.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 94,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "Al",
#                         "boundingBox": [
#                             527.0,
#                             380.0,
#                             589.0,
#                             380.0,
#                             587.0,
#                             436.0,
#                             525.0,
#                             435.0
#                         ],
#                         "confidence": 0.806,
#                         "span": {
#                             "offset": 104,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Research",
#                         "boundingBox": [
#                             599.0,
#                             380.0,
#                             830.0,
#                             383.0,
#                             829.0,
#                             439.0,
#                             598.0,
#                             436.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 107,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "and",
#                         "boundingBox": [
#                             849.0,
#                             383.0,
#                             946.0,
#                             385.0,
#                             945.0,
#                             440.0,
#                             848.0,
#                             439.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 116,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "Main",
#                         "boundingBox": [
#                             1396.0,
#                             383.0,
#                             1515.0,
#                             384.0,
#                             1514.0,
#                             431.0,
#                             1396.0,
#                             430.0
#                         ],
#                         "confidence": 0.989,
#                         "span": {
#                             "offset": 120,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "+886",
#                         "boundingBox": [
#                             1603.0,
#                             385.0,
#                             1714.0,
#                             384.0,
#                             1714.0,
#                             430.0,
#                             1602.0,
#                             427.0
#                         ],
#                         "confidence": 0.986,
#                         "span": {
#                             "offset": 125,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "2",
#                         "boundingBox": [
#                             1733.0,
#                             383.0,
#                             1760.0,
#                             383.0,
#                             1760.0,
#                             431.0,
#                             1733.0,
#                             430.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 130,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "3725",
#                         "boundingBox": [
#                             1776.0,
#                             383.0,
#                             1891.0,
#                             383.0,
#                             1891.0,
#                             431.0,
#                             1776.0,
#                             431.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 132,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "3888",
#                         "boundingBox": [
#                             1910.0,
#                             383.0,
#                             2025.0,
#                             384.0,
#                             2026.0,
#                             429.0,
#                             1910.0,
#                             431.0
#                         ],
#                         "confidence": 0.989,
#                         "span": {
#                             "offset": 137,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Development",
#                         "boundingBox": [
#                             260.0,
#                             445.0,
#                             603.0,
#                             448.0,
#                             602.0,
#                             508.0,
#                             260.0,
#                             505.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 142,
#                             "length": 11
#                         }
#                     },
#                     {
#                         "content": "Center,",
#                         "boundingBox": [
#                             614.0,
#                             448.0,
#                             803.0,
#                             451.0,
#                             803.0,
#                             508.0,
#                             614.0,
#                             508.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 154,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "Taiwan",
#                         "boundingBox": [
#                             815.0,
#                             451.0,
#                             980.0,
#                             453.0,
#                             979.0,
#                             507.0,
#                             814.0,
#                             508.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 162,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Fax",
#                         "boundingBox": [
#                             1403.0,
#                             445.0,
#                             1477.0,
#                             450.0,
#                             1474.0,
#                             491.0,
#                             1402.0,
#                             487.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 169,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "+886",
#                         "boundingBox": [
#                             1604.0,
#                             444.0,
#                             1720.0,
#                             445.0,
#                             1719.0,
#                             492.0,
#                             1602.0,
#                             490.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 173,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "2",
#                         "boundingBox": [
#                             1739.0,
#                             445.0,
#                             1766.0,
#                             445.0,
#                             1765.0,
#                             492.0,
#                             1738.0,
#                             492.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 178,
#                             "length": 1
#                         }
#                     },
#                     {
#                         "content": "3725",
#                         "boundingBox": [
#                             1782.0,
#                             445.0,
#                             1899.0,
#                             445.0,
#                             1899.0,
#                             493.0,
#                             1782.0,
#                             492.0
#                         ],
#                         "confidence": 0.986,
#                         "span": {
#                             "offset": 180,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "3999",
#                         "boundingBox": [
#                             1915.0,
#                             445.0,
#                             2029.0,
#                             445.0,
#                             2029.0,
#                             493.0,
#                             1915.0,
#                             493.0
#                         ],
#                         "confidence": 0.99,
#                         "span": {
#                             "offset": 185,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "Customer",
#                         "boundingBox": [
#                             1405.0,
#                             506.0,
#                             1638.0,
#                             507.0,
#                             1637.0,
#                             556.0,
#                             1403.0,
#                             556.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 190,
#                             "length": 8
#                         }
#                     },
#                     {
#                         "content": "Service",
#                         "boundingBox": [
#                             1647.0,
#                             507.0,
#                             1820.0,
#                             507.0,
#                             1820.0,
#                             556.0,
#                             1647.0,
#                             556.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 199,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "Center",
#                         "boundingBox": [
#                             1833.0,
#                             508.0,
#                             2001.0,
#                             509.0,
#                             2001.0,
#                             556.0,
#                             1833.0,
#                             556.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 207,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "00801",
#                         "boundingBox": [
#                             1648.0,
#                             570.0,
#                             1791.0,
#                             570.0,
#                             1790.0,
#                             618.0,
#                             1646.0,
#                             618.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 214,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "128",
#                         "boundingBox": [
#                             1808.0,
#                             570.0,
#                             1895.0,
#                             570.0,
#                             1895.0,
#                             618.0,
#                             1807.0,
#                             618.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 220,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "000",
#                         "boundingBox": [
#                             1912.0,
#                             569.0,
#                             1999.0,
#                             569.0,
#                             1999.0,
#                             617.0,
#                             1911.0,
#                             617.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 224,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "Microsoft",
#                         "boundingBox": [
#                             1419.0,
#                             901.0,
#                             1701.0,
#                             899.0,
#                             1701.0,
#                             966.0,
#                             1419.0,
#                             960.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 228,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "Taiwan",
#                         "boundingBox": [
#                             1714.0,
#                             899.0,
#                             1918.0,
#                             899.0,
#                             1918.0,
#                             968.0,
#                             1714.0,
#                             966.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 238,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Corporation",
#                         "boundingBox": [
#                             1932.0,
#                             899.0,
#                             2289.0,
#                             899.0,
#                             2289.0,
#                             967.0,
#                             1932.0,
#                             968.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 245,
#                             "length": 11
#                         }
#                     },
#                     {
#                         "content": "18F",
#                         "boundingBox": [
#                             1422.0,
#                             980.0,
#                             1492.0,
#                             979.0,
#                             1492.0,
#                             1039.0,
#                             1421.0,
#                             1038.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 257,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": ".,",
#                         "boundingBox": [
#                             1504.0,
#                             979.0,
#                             1525.0,
#                             979.0,
#                             1525.0,
#                             1040.0,
#                             1504.0,
#                             1039.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 261,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "No.",
#                         "boundingBox": [
#                             1538.0,
#                             979.0,
#                             1625.0,
#                             979.0,
#                             1624.0,
#                             1041.0,
#                             1537.0,
#                             1040.0
#                         ],
#                         "confidence": 0.998,
#                         "span": {
#                             "offset": 264,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "68,",
#                         "boundingBox": [
#                             1637.0,
#                             978.0,
#                             1712.0,
#                             978.0,
#                             1711.0,
#                             1041.0,
#                             1637.0,
#                             1041.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 268,
#                             "length": 3
#                         }
#                     },
#                     {
#                         "content": "Sec.",
#                         "boundingBox": [
#                             1724.0,
#                             978.0,
#                             1820.0,
#                             977.0,
#                             1818.0,
#                             1041.0,
#                             1723.0,
#                             1041.0
#                         ],
#                         "confidence": 0.987,
#                         "span": {
#                             "offset": 272,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": "5,",
#                         "boundingBox": [
#                             1832.0,
#                             977.0,
#                             1873.0,
#                             977.0,
#                             1872.0,
#                             1041.0,
#                             1831.0,
#                             1041.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 277,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Zhongxiao",
#                         "boundingBox": [
#                             1886.0,
#                             977.0,
#                             2147.0,
#                             976.0,
#                             2145.0,
#                             1041.0,
#                             1885.0,
#                             1041.0
#                         ],
#                         "confidence": 0.97,
#                         "span": {
#                             "offset": 280,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "E.",
#                         "boundingBox": [
#                             2159.0,
#                             976.0,
#                             2201.0,
#                             975.0,
#                             2199.0,
#                             1040.0,
#                             2158.0,
#                             1040.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 290,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Rd",
#                         "boundingBox": [
#                             2213.0,
#                             975.0,
#                             2263.0,
#                             975.0,
#                             2261.0,
#                             1039.0,
#                             2211.0,
#                             1040.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 293,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": ".,",
#                         "boundingBox": [
#                             2276.0,
#                             975.0,
#                             2306.0,
#                             975.0,
#                             2303.0,
#                             1039.0,
#                             2273.0,
#                             1039.0
#                         ],
#                         "confidence": 0.955,
#                         "span": {
#                             "offset": 296,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Xinyi",
#                         "boundingBox": [
#                             1421.0,
#                             1051.0,
#                             1547.0,
#                             1050.0,
#                             1547.0,
#                             1116.0,
#                             1420.0,
#                             1113.0
#                         ],
#                         "confidence": 0.993,
#                         "span": {
#                             "offset": 299,
#                             "length": 5
#                         }
#                     },
#                     {
#                         "content": "Dist",
#                         "boundingBox": [
#                             1561.0,
#                             1049.0,
#                             1648.0,
#                             1048.0,
#                             1648.0,
#                             1116.0,
#                             1560.0,
#                             1116.0
#                         ],
#                         "confidence": 0.99,
#                         "span": {
#                             "offset": 305,
#                             "length": 4
#                         }
#                     },
#                     {
#                         "content": ".,",
#                         "boundingBox": [
#                             1661.0,
#                             1048.0,
#                             1692.0,
#                             1048.0,
#                             1692.0,
#                             1116.0,
#                             1661.0,
#                             1116.0
#                         ],
#                         "confidence": 0.991,
#                         "span": {
#                             "offset": 310,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "Taipei",
#                         "boundingBox": [
#                             1705.0,
#                             1048.0,
#                             1854.0,
#                             1047.0,
#                             1856.0,
#                             1116.0,
#                             1706.0,
#                             1116.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 313,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "11065,",
#                         "boundingBox": [
#                             1868.0,
#                             1047.0,
#                             2044.0,
#                             1046.0,
#                             2046.0,
#                             1111.0,
#                             1869.0,
#                             1116.0
#                         ],
#                         "confidence": 0.997,
#                         "span": {
#                             "offset": 320,
#                             "length": 6
#                         }
#                     },
#                     {
#                         "content": "Microsoft",
#                         "boundingBox": [
#                             438.0,
#                             1121.0,
#                             1137.0,
#                             1107.0,
#                             1137.0,
#                             1258.0,
#                             446.0,
#                             1268.0
#                         ],
#                         "confidence": 0.994,
#                         "span": {
#                             "offset": 327,
#                             "length": 9
#                         }
#                     },
#                     {
#                         "content": "Taiwan,",
#                         "boundingBox": [
#                             1431.0,
#                             1124.0,
#                             1618.0,
#                             1121.0,
#                             1619.0,
#                             1181.0,
#                             1431.0,
#                             1183.0
#                         ],
#                         "confidence": 0.996,
#                         "span": {
#                             "offset": 337,
#                             "length": 7
#                         }
#                     },
#                     {
#                         "content": "R.O.C.",
#                         "boundingBox": [
#                             1629.0,
#                             1121.0,
#                             1791.0,
#                             1120.0,
#                             1793.0,
#                             1180.0,
#                             1631.0,
#                             1181.0
#                         ],
#                         "confidence": 0.995,
#                         "span": {
#                             "offset": 345,
#                             "length": 6
#                         }
#                     }
#                 ],
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 351
#                     }
#                 ],
#                 "lines": [
#                     {
#                         "content": "John Doe",
#                         "boundingBox": [
#                             279.0,
#                             186.0,
#                             749.0,
#                             193.0,
#                             748.0,
#                             274.0,
#                             278.0,
#                             267.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 0,
#                                 "length": 8
#                             }
#                         ]
#                     },
#                     {
#                         "content": "John.Doe@microsoft.com",
#                         "boundingBox": [
#                             1391.0,
#                             200.0,
#                             1996.0,
#                             205.0,
#                             1995.0,
#                             253.0,
#                             1391.0,
#                             249.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 9,
#                                 "length": 22
#                             }
#                         ]
#                     },
#                     {
#                         "content": "http://www.microsoft.com/taiwan",
#                         "boundingBox": [
#                             1393.0,
#                             261.0,
#                             2186.0,
#                             265.0,
#                             2186.0,
#                             315.0,
#                             1393.0,
#                             312.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 32,
#                                 "length": 31
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Software Development Engineer",
#                         "boundingBox": [
#                             271.0,
#                             310.0,
#                             1110.0,
#                             322.0,
#                             1109.0,
#                             382.0,
#                             270.0,
#                             366.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 64,
#                                 "length": 29
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Microsoft Al Research and",
#                         "boundingBox": [
#                             265.0,
#                             378.0,
#                             952.0,
#                             384.0,
#                             951.0,
#                             439.0,
#                             265.0,
#                             431.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 94,
#                                 "length": 25
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Main",
#                         "boundingBox": [
#                             1395.0,
#                             383.0,
#                             1523.0,
#                             384.0,
#                             1523.0,
#                             431.0,
#                             1394.0,
#                             429.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 120,
#                                 "length": 4
#                             }
#                         ]
#                     },
#                     {
#                         "content": "+886 2 3725 3888",
#                         "boundingBox": [
#                             1602.0,
#                             382.0,
#                             2032.0,
#                             382.0,
#                             2032.0,
#                             430.0,
#                             1602.0,
#                             430.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 125,
#                                 "length": 16
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Development Center, Taiwan",
#                         "boundingBox": [
#                             260.0,
#                             444.0,
#                             988.0,
#                             449.0,
#                             987.0,
#                             508.0,
#                             259.0,
#                             505.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 142,
#                                 "length": 26
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Fax",
#                         "boundingBox": [
#                             1403.0,
#                             445.0,
#                             1483.0,
#                             450.0,
#                             1483.0,
#                             492.0,
#                             1402.0,
#                             487.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 169,
#                                 "length": 3
#                             }
#                         ]
#                     },
#                     {
#                         "content": "+886 2 3725 3999",
#                         "boundingBox": [
#                             1602.0,
#                             444.0,
#                             2041.0,
#                             445.0,
#                             2041.0,
#                             492.0,
#                             1602.0,
#                             491.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 173,
#                                 "length": 16
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Customer Service Center",
#                         "boundingBox": [
#                             1403.0,
#                             506.0,
#                             2001.0,
#                             506.0,
#                             2001.0,
#                             556.0,
#                             1403.0,
#                             555.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 190,
#                                 "length": 23
#                             }
#                         ]
#                     },
#                     {
#                         "content": "00801 128 000",
#                         "boundingBox": [
#                             1646.0,
#                             569.0,
#                             2008.0,
#                             569.0,
#                             2008.0,
#                             616.0,
#                             1646.0,
#                             617.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 214,
#                                 "length": 13
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Microsoft Taiwan Corporation",
#                         "boundingBox": [
#                             1418.0,
#                             898.0,
#                             2298.0,
#                             898.0,
#                             2297.0,
#                             967.0,
#                             1418.0,
#                             965.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 228,
#                                 "length": 28
#                             }
#                         ]
#                     },
#                     {
#                         "content": "18F ., No. 68, Sec. 5, Zhongxiao E. Rd .,",
#                         "boundingBox": [
#                             1418.0,
#                             977.0,
#                             2306.0,
#                             974.0,
#                             2306.0,
#                             1039.0,
#                             1418.0,
#                             1041.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 257,
#                                 "length": 41
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Xinyi Dist ., Taipei 11065,",
#                         "boundingBox": [
#                             1419.0,
#                             1049.0,
#                             2045.0,
#                             1045.0,
#                             2045.0,
#                             1113.0,
#                             1419.0,
#                             1116.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 299,
#                                 "length": 27
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Microsoft",
#                         "boundingBox": [
#                             437.0,
#                             1119.0,
#                             1136.0,
#                             1107.0,
#                             1137.0,
#                             1259.0,
#                             440.0,
#                             1268.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 327,
#                                 "length": 9
#                             }
#                         ]
#                     },
#                     {
#                         "content": "Taiwan, R.O.C.",
#                         "boundingBox": [
#                             1430.0,
#                             1122.0,
#                             1792.0,
#                             1120.0,
#                             1792.0,
#                             1179.0,
#                             1431.0,
#                             1182.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 337,
#                                 "length": 14
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "styles": [],
#         "modelVersion": "2022-04-30"
#     },
#     "denseCaptionsResult": {
#         "values": [
#             {
#                 "text": "a business card on a table",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 2448,
#                     "h": 1632
#                 }
#             },
#             {
#                 "text": "a business card with black text and black text",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 41,
#                     "y": 31,
#                     "w": 2361,
#                     "h": 1436
#                 }
#             },
#             {
#                 "text": "a black letter on a white surface",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 543,
#                     "y": 179,
#                     "w": 89,
#                     "h": 94
#                 }
#             },
#             {
#                 "text": "a close up of a logo",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 176,
#                     "y": 1077,
#                     "w": 227,
#                     "h": 220
#                 }
#             },
#             {
#                 "text": "a close up of a sign",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 1386,
#                     "y": 863,
#                     "w": 899,
#                     "h": 297
#                 }
#             },
#             {
#                 "text": "a black letter o on a white surface",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 931,
#                     "y": 1143,
#                     "w": 99,
#                     "h": 112
#                 }
#             },
#             {
#                 "text": "a red square on a white surface",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 194,
#                     "y": 1084,
#                     "w": 112,
#                     "h": 107
#                 }
#             },
#             {
#                 "text": "a close up of a square",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 286,
#                     "y": 1079,
#                     "w": 117,
#                     "h": 213
#                 }
#             },
#             {
#                 "text": "a black letter o on a white surface",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 766,
#                     "y": 1141,
#                     "w": 94,
#                     "h": 113
#                 }
#             },
#             {
#                 "text": "a close up of a sign",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 420,
#                     "y": 1086,
#                     "w": 724,
#                     "h": 193
#                 }
#             }
#         ]
#     },
#     "modelVersion": "2023-02-01-preview",
#     "metadata": {
#         "width": 2448,
#         "height": 1632
#     },
#     "tagsResult": {
#         "values": [
#             {
#                 "name": "text",
#                 "confidence": 0.9999979734420776
#             },
#             {
#                 "name": "businesscard",
#                 "confidence": 0.995883584022522
#             }
#         ]
#     },
#     "smartCropsResult": {
#         "values": [
#             {
#                 "aspectRatio": 1.5,
#                 "boundingBox": {
#                     "x": 102,
#                     "y": 68,
#                     "w": 2244,
#                     "h": 1496
#                 }
#             }
#         ]
#     },
#     "peopleResult": {
#         "values": []
#     }
# }

# %%
print(results["readResult"]["content"])
# Out:
# John Doe
# John.Doe@microsoft.com
# http://www.microsoft.com/taiwan
# Software Development Engineer
# Microsoft Al Research and
# Main
# +886 2 3725 3888
# Development Center, Taiwan
# Fax
# +886 2 3725 3999
# Customer Service Center
# 00801 128 000
# Microsoft Taiwan Corporation
# 18F ., No. 68, Sec. 5, Zhongxiao E. Rd .,
# Xinyi Dist ., Taipei 11065,
# Microsoft
# Taiwan, R.O.C.

# %% [markdown]
# ## Test 4

# %%
image_file = os.path.join(IMAGES_DIR, "street.jpg")

img = Image.open(image_file)
img.thumbnail((640, 640), Image.LANCZOS)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x401>

# %%
with open(image_file, "rb") as f:
    data = f.read()

r = requests.post(url, data=data, headers=headers)

results = r.json()
pprintjson(results)
# Out:
# {
#     "captionResult": {
#         "text": "a group of people riding bicycles in a city",
#         "confidence": 1.0
#     },
#     "objectsResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 941,
#                     "y": 466,
#                     "w": 64,
#                     "h": 138
#                 },
#                 "tags": [
#                     {
#                         "name": "person",
#                         "confidence": 0.622
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 1053,
#                     "y": 466,
#                     "w": 70,
#                     "h": 127
#                 },
#                 "tags": [
#                     {
#                         "name": "person",
#                         "confidence": 0.555
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 598,
#                     "y": 628,
#                     "w": 46,
#                     "h": 92
#                 },
#                 "tags": [
#                     {
#                         "name": "Bicycle wheel",
#                         "confidence": 0.531
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 19,
#                     "y": 16,
#                     "w": 142,
#                     "h": 549
#                 },
#                 "tags": [
#                     {
#                         "name": "house",
#                         "confidence": 0.554
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 599,
#                     "y": 459,
#                     "w": 116,
#                     "h": 254
#                 },
#                 "tags": [
#                     {
#                         "name": "person",
#                         "confidence": 0.717
#                     }
#                 ]
#             },
#             {
#                 "boundingBox": {
#                     "x": 584,
#                     "y": 576,
#                     "w": 155,
#                     "h": 173
#                 },
#                 "tags": [
#                     {
#                         "name": "bicycle",
#                         "confidence": 0.688
#                     }
#                 ]
#             }
#         ]
#     },
#     "readResult": {
#         "stringIndexType": "TextElements",
#         "content": "20\n20",
#         "pages": [
#             {
#                 "height": 756.0,
#                 "width": 1206.0,
#                 "angle": 2.1994,
#                 "pageNumber": 1,
#                 "words": [
#                     {
#                         "content": "20",
#                         "boundingBox": [
#                             1009.0,
#                             396.0,
#                             1020.0,
#                             396.0,
#                             1020.0,
#                             406.0,
#                             1008.0,
#                             405.0
#                         ],
#                         "confidence": 0.975,
#                         "span": {
#                             "offset": 0,
#                             "length": 2
#                         }
#                     },
#                     {
#                         "content": "20",
#                         "boundingBox": [
#                             70.0,
#                             453.0,
#                             88.0,
#                             453.0,
#                             88.0,
#                             467.0,
#                             71.0,
#                             468.0
#                         ],
#                         "confidence": 0.847,
#                         "span": {
#                             "offset": 3,
#                             "length": 2
#                         }
#                     }
#                 ],
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 5
#                     }
#                 ],
#                 "lines": [
#                     {
#                         "content": "20",
#                         "boundingBox": [
#                             1008.0,
#                             396.0,
#                             1021.0,
#                             396.0,
#                             1020.0,
#                             406.0,
#                             1007.0,
#                             405.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 0,
#                                 "length": 2
#                             }
#                         ]
#                     },
#                     {
#                         "content": "20",
#                         "boundingBox": [
#                             68.0,
#                             453.0,
#                             87.0,
#                             453.0,
#                             88.0,
#                             467.0,
#                             68.0,
#                             468.0
#                         ],
#                         "spans": [
#                             {
#                                 "offset": 3,
#                                 "length": 2
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "styles": [
#             {
#                 "isHandwritten": true,
#                 "spans": [
#                     {
#                         "offset": 0,
#                         "length": 2
#                     }
#                 ],
#                 "confidence": 0.6
#             }
#         ],
#         "modelVersion": "2022-04-30"
#     },
#     "denseCaptionsResult": {
#         "values": [
#             {
#                 "text": "a group of people riding bicycles in a city",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 0,
#                     "y": 0,
#                     "w": 1206,
#                     "h": 756
#                 }
#             },
#             {
#                 "text": "a person riding a bicycle with a basket of dog",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 584,
#                     "y": 459,
#                     "w": 154,
#                     "h": 283
#                 }
#             },
#             {
#                 "text": "a person riding a bike",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 1029,
#                     "y": 449,
#                     "w": 105,
#                     "h": 161
#                 }
#             },
#             {
#                 "text": "a person riding a bike",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 833,
#                     "y": 458,
#                     "w": 64,
#                     "h": 123
#                 }
#             },
#             {
#                 "text": "a person riding a bicycle",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 194,
#                     "y": 492,
#                     "w": 71,
#                     "h": 147
#                 }
#             },
#             {
#                 "text": "a person riding a bicycle",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 927,
#                     "y": 451,
#                     "w": 86,
#                     "h": 173
#                 }
#             },
#             {
#                 "text": "a person riding a bicycle with a dog in a basket",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 20,
#                     "y": 471,
#                     "w": 1167,
#                     "h": 264
#                 }
#             },
#             {
#                 "text": "a man riding a bike",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 837,
#                     "y": 470,
#                     "w": 51,
#                     "h": 64
#                 }
#             },
#             {
#                 "text": "a building with a street sign",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 8,
#                     "y": 8,
#                     "w": 1190,
#                     "h": 453
#                 }
#             },
#             {
#                 "text": "a group of people riding bicycles in front of a building",
#                 "confidence": 1.0,
#                 "boundingBox": {
#                     "x": 574,
#                     "y": 0,
#                     "w": 450,
#                     "h": 521
#                 }
#             }
#         ]
#     },
#     "modelVersion": "2023-02-01-preview",
#     "metadata": {
#         "width": 1206,
#         "height": 756
#     },
#     "tagsResult": {
#         "values": [
#             {
#                 "name": "outdoor",
#                 "confidence": 0.9991688132286072
#             },
#             {
#                 "name": "building",
#                 "confidence": 0.9910473823547363
#             },
#             {
#                 "name": "road",
#                 "confidence": 0.9782278537750244
#             },
#             {
#                 "name": "sky",
#                 "confidence": 0.9767833352088928
#             },
#             {
#                 "name": "street",
#                 "confidence": 0.9664870500564575
#             },
#             {
#                 "name": "bicycle wheel",
#                 "confidence": 0.9168410301208496
#             },
#             {
#                 "name": "land vehicle",
#                 "confidence": 0.9047801494598389
#             },
#             {
#                 "name": "vehicle",
#                 "confidence": 0.8851263523101807
#             },
#             {
#                 "name": "pedestrian",
#                 "confidence": 0.8809370994567871
#             },
#             {
#                 "name": "town",
#                 "confidence": 0.8585145473480225
#             },
#             {
#                 "name": "lane",
#                 "confidence": 0.8428642749786377
#             },
#             {
#                 "name": "city",
#                 "confidence": 0.7800877094268799
#             },
#             {
#                 "name": "bicycle",
#                 "confidence": 0.7626770734786987
#             },
#             {
#                 "name": "way",
#                 "confidence": 0.7023184299468994
#             },
#             {
#                 "name": "person",
#                 "confidence": 0.6829561591148376
#             },
#             {
#                 "name": "people",
#                 "confidence": 0.6704760789871216
#             },
#             {
#                 "name": "bike",
#                 "confidence": 0.47887974977493286
#             },
#             {
#                 "name": "winter",
#                 "confidence": 0.4375836253166199
#             }
#         ]
#     },
#     "smartCropsResult": {
#         "values": [
#             {
#                 "aspectRatio": 1.31,
#                 "boundingBox": {
#                     "x": 50,
#                     "y": 32,
#                     "w": 905,
#                     "h": 692
#                 }
#             }
#         ]
#     },
#     "peopleResult": {
#         "values": [
#             {
#                 "boundingBox": {
#                     "x": 599,
#                     "y": 464,
#                     "w": 112,
#                     "h": 242
#                 },
#                 "confidence": 0.888308048248291
#             },
#             {
#                 "boundingBox": {
#                     "x": 202,
#                     "y": 495,
#                     "w": 62,
#                     "h": 135
#                 },
#                 "confidence": 0.8724349737167358
#             },
#             {
#                 "boundingBox": {
#                     "x": 838,
#                     "y": 463,
#                     "w": 60,
#                     "h": 115
#                 },
#                 "confidence": 0.8654031157493591
#             },
#             {
#                 "boundingBox": {
#                     "x": 939,
#                     "y": 454,
#                     "w": 71,
#                     "h": 153
#                 },
#                 "confidence": 0.861977756023407
#             },
#             {
#                 "boundingBox": {
#                     "x": 1046,
#                     "y": 453,
#                     "w": 81,
#                     "h": 147
#                 },
#                 "confidence": 0.8559510111808777
#             },
#             {
#                 "boundingBox": {
#                     "x": 449,
#                     "y": 477,
#                     "w": 29,
#                     "h": 77
#                 },
#                 "confidence": 0.7287445664405823
#             },
#             {
#                 "boundingBox": {
#                     "x": 470,
#                     "y": 489,
#                     "w": 33,
#                     "h": 65
#                 },
#                 "confidence": 0.7216660380363464
#             },
#             {
#                 "boundingBox": {
#                     "x": 794,
#                     "y": 462,
#                     "w": 42,
#                     "h": 82
#                 },
#                 "confidence": 0.7131901979446411
#             },
#             {
#                 "boundingBox": {
#                     "x": 694,
#                     "y": 464,
#                     "w": 37,
#                     "h": 80
#                 },
#                 "confidence": 0.69422447681427
#             },
#             {
#                 "boundingBox": {
#                     "x": 579,
#                     "y": 475,
#                     "w": 25,
#                     "h": 58
#                 },
#                 "confidence": 0.64215087890625
#             },
#             {
#                 "boundingBox": {
#                     "x": 609,
#                     "y": 473,
#                     "w": 26,
#                     "h": 66
#                 },
#                 "confidence": 0.640379011631012
#             },
#             {
#                 "boundingBox": {
#                     "x": 753,
#                     "y": 459,
#                     "w": 32,
#                     "h": 67
#                 },
#                 "confidence": 0.42877620458602905
#             },
#             {
#                 "boundingBox": {
#                     "x": 782,
#                     "y": 462,
#                     "w": 29,
#                     "h": 62
#                 },
#                 "confidence": 0.14011546969413757
#             },
#             {
#                 "boundingBox": {
#                     "x": 773,
#                     "y": 461,
#                     "w": 25,
#                     "h": 59
#                 },
#                 "confidence": 0.11357738822698593
#             },
#             {
#                 "boundingBox": {
#                     "x": 686,
#                     "y": 464,
#                     "w": 26,
#                     "h": 62
#                 },
#                 "confidence": 0.021749189123511314
#             },
#             {
#                 "boundingBox": {
#                     "x": 780,
#                     "y": 462,
#                     "w": 15,
#                     "h": 35
#                 },
#                 "confidence": 0.01999715529382229
#             },
#             {
#                 "boundingBox": {
#                     "x": 445,
#                     "y": 497,
#                     "w": 21,
#                     "h": 56
#                 },
#                 "confidence": 0.010138620622456074
#             },
#             {
#                 "boundingBox": {
#                     "x": 759,
#                     "y": 456,
#                     "w": 66,
#                     "h": 87
#                 },
#                 "confidence": 0.006766785401850939
#             },
#             {
#                 "boundingBox": {
#                     "x": 345,
#                     "y": 478,
#                     "w": 13,
#                     "h": 21
#                 },
#                 "confidence": 0.003980359528213739
#             },
#             {
#                 "boundingBox": {
#                     "x": 540,
#                     "y": 476,
#                     "w": 21,
#                     "h": 40
#                 },
#                 "confidence": 0.003925149794667959
#             },
#             {
#                 "boundingBox": {
#                     "x": 804,
#                     "y": 461,
#                     "w": 28,
#                     "h": 38
#                 },
#                 "confidence": 0.0032133141066879034
#             },
#             {
#                 "boundingBox": {
#                     "x": 339,
#                     "y": 481,
#                     "w": 12,
#                     "h": 18
#                 },
#                 "confidence": 0.002661517122760415
#             },
#             {
#                 "boundingBox": {
#                     "x": 1128,
#                     "y": 455,
#                     "w": 17,
#                     "h": 28
#                 },
#                 "confidence": 0.002085214015096426
#             },
#             {
#                 "boundingBox": {
#                     "x": 486,
#                     "y": 481,
#                     "w": 23,
#                     "h": 39
#                 },
#                 "confidence": 0.001912059378810227
#             },
#             {
#                 "boundingBox": {
#                     "x": 369,
#                     "y": 478,
#                     "w": 13,
#                     "h": 19
#                 },
#                 "confidence": 0.0014456233475357294
#             },
#             {
#                 "boundingBox": {
#                     "x": 831,
#                     "y": 397,
#                     "w": 17,
#                     "h": 27
#                 },
#                 "confidence": 0.0014278007438406348
#             },
#             {
#                 "boundingBox": {
#                     "x": 496,
#                     "y": 434,
#                     "w": 346,
#                     "h": 278
#                 },
#                 "confidence": 0.0013340602163225412
#             },
#             {
#                 "boundingBox": {
#                     "x": 453,
#                     "y": 474,
#                     "w": 24,
#                     "h": 33
#                 },
#                 "confidence": 0.0012029370991513133
#             },
#             {
#                 "boundingBox": {
#                     "x": 1195,
#                     "y": 437,
#                     "w": 9,
#                     "h": 30
#                 },
#                 "confidence": 0.0011312656570225954
#             }
#         ]
#     }
# }

# %%
pprintjson(results["captionResult"])
# Out:
# {
#     "text": "a group of people riding bicycles in a city",
#     "confidence": 1.0
# }

# %%
pprintjson(results["objectsResult"])
# Out:
# {
#     "values": [
#         {
#             "boundingBox": {
#                 "x": 941,
#                 "y": 466,
#                 "w": 64,
#                 "h": 138
#             },
#             "tags": [
#                 {
#                     "name": "person",
#                     "confidence": 0.622
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 1053,
#                 "y": 466,
#                 "w": 70,
#                 "h": 127
#             },
#             "tags": [
#                 {
#                     "name": "person",
#                     "confidence": 0.555
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 598,
#                 "y": 628,
#                 "w": 46,
#                 "h": 92
#             },
#             "tags": [
#                 {
#                     "name": "Bicycle wheel",
#                     "confidence": 0.531
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 19,
#                 "y": 16,
#                 "w": 142,
#                 "h": 549
#             },
#             "tags": [
#                 {
#                     "name": "house",
#                     "confidence": 0.554
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 599,
#                 "y": 459,
#                 "w": 116,
#                 "h": 254
#             },
#             "tags": [
#                 {
#                     "name": "person",
#                     "confidence": 0.717
#                 }
#             ]
#         },
#         {
#             "boundingBox": {
#                 "x": 584,
#                 "y": 576,
#                 "w": 155,
#                 "h": 173
#             },
#             "tags": [
#                 {
#                     "name": "bicycle",
#                     "confidence": 0.688
#                 }
#             ]
#         }
#     ]
# }

# %%
pprintjson(results["denseCaptionsResult"])
# Out:
# {
#     "values": [
#         {
#             "text": "a group of people riding bicycles in a city",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 0,
#                 "y": 0,
#                 "w": 1206,
#                 "h": 756
#             }
#         },
#         {
#             "text": "a person riding a bicycle with a basket of dog",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 584,
#                 "y": 459,
#                 "w": 154,
#                 "h": 283
#             }
#         },
#         {
#             "text": "a person riding a bike",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 1029,
#                 "y": 449,
#                 "w": 105,
#                 "h": 161
#             }
#         },
#         {
#             "text": "a person riding a bike",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 833,
#                 "y": 458,
#                 "w": 64,
#                 "h": 123
#             }
#         },
#         {
#             "text": "a person riding a bicycle",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 194,
#                 "y": 492,
#                 "w": 71,
#                 "h": 147
#             }
#         },
#         {
#             "text": "a person riding a bicycle",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 927,
#                 "y": 451,
#                 "w": 86,
#                 "h": 173
#             }
#         },
#         {
#             "text": "a person riding a bicycle with a dog in a basket",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 20,
#                 "y": 471,
#                 "w": 1167,
#                 "h": 264
#             }
#         },
#         {
#             "text": "a man riding a bike",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 837,
#                 "y": 470,
#                 "w": 51,
#                 "h": 64
#             }
#         },
#         {
#             "text": "a building with a street sign",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 8,
#                 "y": 8,
#                 "w": 1190,
#                 "h": 453
#             }
#         },
#         {
#             "text": "a group of people riding bicycles in front of a building",
#             "confidence": 1.0,
#             "boundingBox": {
#                 "x": 574,
#                 "y": 0,
#                 "w": 450,
#                 "h": 521
#             }
#         }
#     ]
# }

# %%
pprintjson(results["tagsResult"])
# Out:
# {
#     "values": [
#         {
#             "name": "outdoor",
#             "confidence": 0.9991688132286072
#         },
#         {
#             "name": "building",
#             "confidence": 0.9910473823547363
#         },
#         {
#             "name": "road",
#             "confidence": 0.9782278537750244
#         },
#         {
#             "name": "sky",
#             "confidence": 0.9767833352088928
#         },
#         {
#             "name": "street",
#             "confidence": 0.9664870500564575
#         },
#         {
#             "name": "bicycle wheel",
#             "confidence": 0.9168410301208496
#         },
#         {
#             "name": "land vehicle",
#             "confidence": 0.9047801494598389
#         },
#         {
#             "name": "vehicle",
#             "confidence": 0.8851263523101807
#         },
#         {
#             "name": "pedestrian",
#             "confidence": 0.8809370994567871
#         },
#         {
#             "name": "town",
#             "confidence": 0.8585145473480225
#         },
#         {
#             "name": "lane",
#             "confidence": 0.8428642749786377
#         },
#         {
#             "name": "city",
#             "confidence": 0.7800877094268799
#         },
#         {
#             "name": "bicycle",
#             "confidence": 0.7626770734786987
#         },
#         {
#             "name": "way",
#             "confidence": 0.7023184299468994
#         },
#         {
#             "name": "person",
#             "confidence": 0.6829561591148376
#         },
#         {
#             "name": "people",
#             "confidence": 0.6704760789871216
#         },
#         {
#             "name": "bike",
#             "confidence": 0.47887974977493286
#         },
#         {
#             "name": "winter",
#             "confidence": 0.4375836253166199
#         }
#     ]
# }

# %%
pprintjson(results["peopleResult"])
# Out:
# {
#     "values": [
#         {
#             "boundingBox": {
#                 "x": 599,
#                 "y": 464,
#                 "w": 112,
#                 "h": 242
#             },
#             "confidence": 0.888308048248291
#         },
#         {
#             "boundingBox": {
#                 "x": 202,
#                 "y": 495,
#                 "w": 62,
#                 "h": 135
#             },
#             "confidence": 0.8724349737167358
#         },
#         {
#             "boundingBox": {
#                 "x": 838,
#                 "y": 463,
#                 "w": 60,
#                 "h": 115
#             },
#             "confidence": 0.8654031157493591
#         },
#         {
#             "boundingBox": {
#                 "x": 939,
#                 "y": 454,
#                 "w": 71,
#                 "h": 153
#             },
#             "confidence": 0.861977756023407
#         },
#         {
#             "boundingBox": {
#                 "x": 1046,
#                 "y": 453,
#                 "w": 81,
#                 "h": 147
#             },
#             "confidence": 0.8559510111808777
#         },
#         {
#             "boundingBox": {
#                 "x": 449,
#                 "y": 477,
#                 "w": 29,
#                 "h": 77
#             },
#             "confidence": 0.7287445664405823
#         },
#         {
#             "boundingBox": {
#                 "x": 470,
#                 "y": 489,
#                 "w": 33,
#                 "h": 65
#             },
#             "confidence": 0.7216660380363464
#         },
#         {
#             "boundingBox": {
#                 "x": 794,
#                 "y": 462,
#                 "w": 42,
#                 "h": 82
#             },
#             "confidence": 0.7131901979446411
#         },
#         {
#             "boundingBox": {
#                 "x": 694,
#                 "y": 464,
#                 "w": 37,
#                 "h": 80
#             },
#             "confidence": 0.69422447681427
#         },
#         {
#             "boundingBox": {
#                 "x": 579,
#                 "y": 475,
#                 "w": 25,
#                 "h": 58
#             },
#             "confidence": 0.64215087890625
#         },
#         {
#             "boundingBox": {
#                 "x": 609,
#                 "y": 473,
#                 "w": 26,
#                 "h": 66
#             },
#             "confidence": 0.640379011631012
#         },
#         {
#             "boundingBox": {
#                 "x": 753,
#                 "y": 459,
#                 "w": 32,
#                 "h": 67
#             },
#             "confidence": 0.42877620458602905
#         },
#         {
#             "boundingBox": {
#                 "x": 782,
#                 "y": 462,
#                 "w": 29,
#                 "h": 62
#             },
#             "confidence": 0.14011546969413757
#         },
#         {
#             "boundingBox": {
#                 "x": 773,
#                 "y": 461,
#                 "w": 25,
#                 "h": 59
#             },
#             "confidence": 0.11357738822698593
#         },
#         {
#             "boundingBox": {
#                 "x": 686,
#                 "y": 464,
#                 "w": 26,
#                 "h": 62
#             },
#             "confidence": 0.021749189123511314
#         },
#         {
#             "boundingBox": {
#                 "x": 780,
#                 "y": 462,
#                 "w": 15,
#                 "h": 35
#             },
#             "confidence": 0.01999715529382229
#         },
#         {
#             "boundingBox": {
#                 "x": 445,
#                 "y": 497,
#                 "w": 21,
#                 "h": 56
#             },
#             "confidence": 0.010138620622456074
#         },
#         {
#             "boundingBox": {
#                 "x": 759,
#                 "y": 456,
#                 "w": 66,
#                 "h": 87
#             },
#             "confidence": 0.006766785401850939
#         },
#         {
#             "boundingBox": {
#                 "x": 345,
#                 "y": 478,
#                 "w": 13,
#                 "h": 21
#             },
#             "confidence": 0.003980359528213739
#         },
#         {
#             "boundingBox": {
#                 "x": 540,
#                 "y": 476,
#                 "w": 21,
#                 "h": 40
#             },
#             "confidence": 0.003925149794667959
#         },
#         {
#             "boundingBox": {
#                 "x": 804,
#                 "y": 461,
#                 "w": 28,
#                 "h": 38
#             },
#             "confidence": 0.0032133141066879034
#         },
#         {
#             "boundingBox": {
#                 "x": 339,
#                 "y": 481,
#                 "w": 12,
#                 "h": 18
#             },
#             "confidence": 0.002661517122760415
#         },
#         {
#             "boundingBox": {
#                 "x": 1128,
#                 "y": 455,
#                 "w": 17,
#                 "h": 28
#             },
#             "confidence": 0.002085214015096426
#         },
#         {
#             "boundingBox": {
#                 "x": 486,
#                 "y": 481,
#                 "w": 23,
#                 "h": 39
#             },
#             "confidence": 0.001912059378810227
#         },
#         {
#             "boundingBox": {
#                 "x": 369,
#                 "y": 478,
#                 "w": 13,
#                 "h": 19
#             },
#             "confidence": 0.0014456233475357294
#         },
#         {
#             "boundingBox": {
#                 "x": 831,
#                 "y": 397,
#                 "w": 17,
#                 "h": 27
#             },
#             "confidence": 0.0014278007438406348
#         },
#         {
#             "boundingBox": {
#                 "x": 496,
#                 "y": 434,
#                 "w": 346,
#                 "h": 278
#             },
#             "confidence": 0.0013340602163225412
#         },
#         {
#             "boundingBox": {
#                 "x": 453,
#                 "y": 474,
#                 "w": 24,
#                 "h": 33
#             },
#             "confidence": 0.0012029370991513133
#         },
#         {
#             "boundingBox": {
#                 "x": 1195,
#                 "y": 437,
#                 "w": 9,
#                 "h": 30
#             },
#             "confidence": 0.0011312656570225954
#         }
#     ]
# }
